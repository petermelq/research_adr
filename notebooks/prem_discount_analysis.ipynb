# %%
import pandas as pd

adr_df = pd.read_csv('../data/processed/adrs/adr_mid_at_ord_auction_adjust_all.csv', index_col=0, parse_dates=True)
#ord_df = pd.read_csv('../data/processed/ordinary/bbg_ord_close_to_usd_adr_PX_LAST_adjust_all.csv', index_col=0, parse_dates=True)

ord_df = pd.read_csv('../data/processed/ordinary/ord_close_to_usd_adr_PX_LAST_adjust_all.csv', index_col=0, parse_dates=True)

# %%
(adr_df['SAN'] / ord_df['SAN SM Equity']).plot()
# Out:
# <Axes: xlabel='date'>

# %%
#(adr_df['SAP']/ord_df['SAP GR Equity']).plot()
# Out:
# <Axes: xlabel='date'>

# %%
import pandas as pd

# pd.read_parquet('')

# %%
import numpy as np
