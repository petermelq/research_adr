# %%
#!/usr/bin/env python
"""
Find missing trading days (as date ranges) in a Parquet dataset, per partition combination,
without ever loading the entire dataset into memory at once.

Key points:
- Dataset is a directory of Parquet files, possibly Hive-partitioned on multiple keys.
- One column is named `date`. It may be:
    * a partition key (e.g. date=2020-01-02/...), or
    * a column stored inside the Parquet files.
- Given [start_date, end_date] and a pandas_market_calendars calendar:
    * Build the trading-day index (days market is open).
    * Enumerate all combinations of non-date partition columns from the directory structure.
    * For each partition combination:
        - Collect the set of dates present for that combo
          (from directory names if date is a partition key, or by reading only that combo’s data).
        - Compute missing trading-day ranges.
- Missing days are reported as contiguous ranges per partition combination.

Requirements:
    pip install pandas pyarrow pandas_market_calendars
"""

import argparse
from collections import defaultdict
from pathlib import Path
from typing import Dict, List, Tuple, Any, Iterable

import os
import pandas as pd
import pyarrow.dataset as ds
import pandas_market_calendars as mcal
import sys
sys.path.append('../src')
import utils


# ----------------------------------------------------------------------
# Trading days utilities
# ----------------------------------------------------------------------

def get_trading_days(
    calendar_name: str, start_date: str, end_date: str
) -> pd.DatetimeIndex:
    """
    Return normalized (midnight) trading days for the given calendar and date range.
    Only days where the market is open are included.
    """
    cal = mcal.get_calendar(calendar_name)
    schedule = cal.schedule(start_date=start_date, end_date=end_date)
    idx = schedule.index  # DatetimeIndex, typically tz-aware

    if idx.tz is not None:
        idx = idx.tz_convert(None)

    return idx.normalize()


def find_missing_ranges(
    expected_days: pd.DatetimeIndex,
    present_days: pd.DatetimeIndex,
) -> List[Tuple[pd.Timestamp, pd.Timestamp]]:
    """
    Given expected trading days and the days present in the data, return a list of
    missing contiguous ranges (start_date, end_date).

    Both inputs should be normalized DatetimeIndex objects.
    """
    if expected_days.empty:
        return []

    present_set = set(present_days)
    missing = [d for d in expected_days if d not in present_set]

    if not missing:
        return []

    pos = {d: i for i, d in enumerate(expected_days)}    

    missing.sort()
    ranges: List[Tuple[pd.Timestamp, pd.Timestamp]] = []

    start = prev = missing[0]
    for d in missing[1:]:
        # If the gap is more than 1 day, we start a new range
        if pos[d] - pos[prev] > 1:
            ranges.append((start, prev))
            start = d
        prev = d
        
    ranges.append((start, prev))

    return ranges


# ----------------------------------------------------------------------
# Partition discovery from filesystem
# ----------------------------------------------------------------------

def parse_partition_components(parts: Iterable[str]) -> Dict[str, str]:
    """
    Parse a sequence of path components like ['exchange=XNYS', 'ticker=AAPL']
    into a dict {'exchange': 'XNYS', 'ticker': 'AAPL'}.
    Components that do not contain '=' are ignored.
    """
    result: Dict[str, str] = {}
    for p in parts:
        if "=" in p:
            key, val = p.split("=", 1)
            result[key] = val
    return result


def discover_partition_combos_from_paths(
    dataset_path: str,
    combo_cols: List[str],
    date_column: str,
) -> Tuple[List[Tuple[Any, ...]], Dict[Tuple[Any, ...], List[pd.Timestamp]]]:
    """
    FAST VERSION:

    Walk the *directory tree* (not individual Parquet files) to discover:

    - All unique combinations of values for `combo_cols` (non-date partition columns).
    - For each combination, the list of dates if `date_column` is a partition key
      in the directory structure.

    Assumes Hive-style partitioning: e.g.
        root/exchange=ARCX.PILLAR/ticker=AEG/date=2020-01-02/part-0.parquet

    Returns:
        combos: list of tuple(combo_values) in the order of combo_cols.
        combo_dates: mapping combo_key -> list of pd.Timestamp (only those combos
                     where `date_column` appears as a partition key).
    """
    dataset_path = os.path.abspath(dataset_path)

    combo_set = set()
    # store date *strings* during walk, convert to Timestamp once at the end
    combo_date_strings: Dict[Tuple[Any, ...], set] = defaultdict(set)

    for dirpath, dirnames, filenames in os.walk(dataset_path):
        rel = os.path.relpath(dirpath, dataset_path)
        if rel == ".":
            # root itself; no partition components here
            continue

        parts = rel.split(os.sep)
        part_dict = parse_partition_components(parts)

        # Build combo key from combo_cols (may be empty tuple if no non-date partition cols)
        combo_key = tuple(part_dict.get(col) for col in combo_cols)
        
        # We only care about directories that actually correspond to some partition level
        if all(val is not None for val in combo_key) or (date_column in part_dict):
            combo_set.add(combo_key)

        # Capture date if it is present as a partition component
        if date_column in part_dict:
            combo_date_strings[combo_key].add(part_dict[date_column])

    combos = sorted(combo_set)
   
    # Convert date strings to normalized Timestamp lists in one shot
    combo_dates: Dict[Tuple[Any, ...], List[pd.Timestamp]] = {}
    for key, date_strs in combo_date_strings.items():
        # sort lexicographically first (cheap), then convert
        sorted_strs = sorted(date_strs)
        ts = pd.to_datetime(sorted_strs).normalize()
        combo_dates[key] = list(ts)

    return combos, combo_dates

# ----------------------------------------------------------------------
# Main computation: missing days by partition combo
# ----------------------------------------------------------------------
def compute_missing_by_partition_streaming(
    dataset_path: str,
    date_column: str,
    trading_days: pd.DatetimeIndex,
) -> pd.DataFrame:
    """
    Streaming-style computation of missing trading-day ranges.

    Strategy:
    - Build a pyarrow.dataset with Hive partitioning (to know partition column names).
    - Determine non-date partition columns (combo_cols).
    - Walk the filesystem to find:
        * all partition combinations (combo_cols),
        * dates present as partition keys (if date_column is a partition key).
    - For each combo:
        * If date_column is a partition key -> get dates from path metadata.
        * Otherwise -> read ONLY that combo's rows from disk (date column only).
    - Compute missing trading-day ranges for each combo.

    Returns:
        DataFrame with columns: combo_cols..., "missing_start", "missing_end"
    """
    # Build dataset; no data read yet, just metadata and schema.
    dataset = ds.dataset(dataset_path, format="parquet", partitioning="hive")

    # Partition columns discovered by Arrow; may be empty
    if dataset.partitioning is not None and dataset.partitioning.schema is not None:
        partition_cols = [field.name for field in dataset.partitioning.schema]
    else:
        partition_cols = []

    # Non-date partition columns define the "partition combination"
    combo_cols = [c for c in partition_cols if c != date_column]

    # Discover partition combinations and (optionally) date values from paths
    combos, combo_dates_from_paths = discover_partition_combos_from_paths(
        dataset_path=dataset_path,
        combo_cols=combo_cols,
        date_column=date_column,
    )

    # Is date effectively a partition column?
    date_is_partition = date_column in partition_cols

    min_td, max_td = trading_days.min(), trading_days.max()

    results_rows: List[Dict[str, Any]] = []

    # Helper to build a pyarrow filter for one combo (only on partition columns)
    def build_partition_filter(combo_key: Tuple[Any, ...]):
        if not combo_cols:
            return None  # no partition filter
        expr = None
        for col_name, value in zip(combo_cols, combo_key):
            # Partition values are strings in Hive layout; compare as strings
            term = ds.field(col_name) == value
            expr = term if expr is None else (expr & term)
        return expr

    for combo_key in combos or [()]:
        # Present days for this combo
        if date_is_partition and combo_key in combo_dates_from_paths:
            # Dates can be computed from folder names; no need to touch file bodies.
            present_days = pd.DatetimeIndex(combo_dates_from_paths[combo_key]).normalize()
            # Restrict to the trading-day window of interest
            present_days = present_days[(present_days >= min_td) & (present_days <= max_td)]
        else:
            # Need to read this combo's data from disk, but only this combo and only the date column.
            partition_filter = build_partition_filter(combo_key)

            # You may optionally add a date-range filter to reduce I/O, e.g.:
            #   date_filter = (ds.field(date_column) >= min_td) & (ds.field(date_column) <= max_td)
            #   full_filter = partition_filter & date_filter if partition_filter is not None else date_filter
            # For simplicity, we only filter on partition columns here.
            full_filter = partition_filter

            table = dataset.to_table(columns=[date_column], filter=full_filter)
            if table.num_rows == 0:
                present_days = pd.DatetimeIndex([])
            else:
                df_dates = table.to_pandas()
                present_days = pd.to_datetime(df_dates[date_column]).dt.normalize().unique()
                present_days = pd.DatetimeIndex(present_days)
                # Restrict to trading window
                present_days = present_days[
                    (present_days >= min_td) & (present_days <= max_td)
                ]

        missing_ranges = find_missing_ranges(trading_days, present_days)

        for start, end in missing_ranges:
            row: Dict[str, Any] = {}
            for col_name, value in zip(combo_cols, combo_key):
                row[col_name] = value
            row["missing_start"] = start.date().isoformat()
            row["missing_end"] = end.date().isoformat()
            results_rows.append(row)

    return pd.DataFrame(results_rows)

def find_first_file_directory(root: str):
    """
    Walk root until the first directory containing any file is found.
    Returns that directory path, or None if no files exist.
    """
    for dirpath, dirnames, filenames in os.walk(root):
        if filenames:
            return dirpath
    return None


def get_partition_field_vals(partition_path, field_names=['exchange','ticker','date']):
    dset = ds.dataset(partition_path, format="parquet", partitioning="hive")
    s = ''.join([str(frag.partition_expression) for frag in dset.get_fragments()])

    field_vals = {}
    for field_name in field_names:
        pattern = re.compile(rf"\({field_name} == \"(?P<{field_name}>[^\"]+)")
        field_vals[field_name] = sorted(set(pattern.findall(s)))

    return field_vals
# ----------------------------------------------------------------------
# CLI
# ----------------------------------------------------------------------
cbday = utils.get_market_business_days('XNYS')
trading_days = pd.date_range('2019-12-15', pd.Timestamp.today().strftime('%Y-%m-%d'), freq=cbday)


if trading_days.empty:
    raise SystemExit("No trading days in the specified range; check dates/calendar.")

# %prun missing_df = compute_missing_by_partition_streaming(dataset_path='../data/raw/adrs/bbo-1m/by_exchange/',date_column='date', trading_days=trading_days, )

# %%
from collections import defaultdict
from typing import List, Tuple
import pandas as pd

def rectangular_groups_by_ticker(df: pd.DataFrame) -> List[Tuple[List[str], List[str]]]:
    """
    Partition (exchange, ticker) pairs into disjoint rectangles by grouping
    tickers that share exactly the same set of exchanges.

    Returns a list of (exchanges, tickers) groups.
    """
    # Work only with unique pairs
    pairs = df[["exchange", "ticker"]].drop_duplicates()

    # For each ticker, compute its set of exchanges
    ticker_to_exset = (
        pairs.groupby("ticker")["exchange"]
        .agg(lambda s: frozenset(s))
    )

    # Group tickers by their exchange-set signature
    exset_to_tickers = defaultdict(list)
    for ticker, ex_set in ticker_to_exset.items():
        exset_to_tickers[ex_set].append(ticker)

    groups = []
    for ex_set, tickers in exset_to_tickers.items():
        exchanges = sorted(ex_set)
        tickers = sorted(tickers)
        groups.append((exchanges, tickers))

    return groups


def rectangular_groups_by_exchange(df: pd.DataFrame) -> List[Tuple[List[str], List[str]]]:
    """
    Symmetric version: group exchanges that share exactly the same set of tickers.
    Returns a list of (exchanges, tickers) groups.
    """
    pairs = df[["exchange", "ticker"]].drop_duplicates()

    # For each exchange, compute its set of tickers
    ex_to_tset = (
        pairs.groupby("exchange")["ticker"]
        .agg(lambda s: frozenset(s))
    )

    # Group exchanges by their ticker-set signature
    tset_to_exchanges = defaultdict(list)
    for ex, t_set in ex_to_tset.items():
        tset_to_exchanges[t_set].append(ex)

    groups = []
    for t_set, exchanges in tset_to_exchanges.items():
        exchanges = sorted(exchanges)
        tickers = sorted(t_set)
        groups.append((exchanges, tickers))

    return groups


def rectangular_groups(df: pd.DataFrame, mode: str = "auto") -> List[Tuple[List[str], List[str]]]:
    """
    High-level helper.

    - mode="ticker": use grouping by ticker signatures only.
    - mode="exchange": use grouping by exchange signatures only.
    - mode="auto": compute both and pick the one with fewer rectangles.
    """
    if mode == "ticker":
        return rectangular_groups_by_ticker(df)
    elif mode == "exchange":
        return rectangular_groups_by_exchange(df)
    elif mode == "auto":
        g_t = rectangular_groups_by_ticker(df)
        g_e = rectangular_groups_by_exchange(df)
        return g_t if len(g_t) <= len(g_e) else g_e
    else:
        raise ValueError("mode must be 'ticker', 'exchange', or 'auto'")

# %%
import os
import re
import sys
import pandas as pd
from glob import glob
sys.path.append('../src')
import utils

def find_first_file_directory(root: str):
    """
    Walk root until the first directory containing any file is found.
    Returns that directory path, or None if no files exist.
    """
    for dirpath, dirnames, filenames in os.walk(root):
        if filenames:
            return dirpath
    
    return None

def get_partition_field_keys(partition_path):
    first_dir = find_first_file_directory(partition_path)
    sep = re.escape(os.sep)
    pattern = re.compile(rf"{sep}(?P<name>[^/=]+)=")
    field_keys = pattern.findall(first_dir)
    
    return field_keys

def get_partition_field_vals(partition_path, field_keys=['exchange','ticker','date']):
    glob_str = os.path.join(partition_path, *('*',)*len(field_keys))
    s = ','.join(glob(glob_str))
    
    print(glob_str,s[:100])
    sep = re.escape(os.sep)
    pattern_str = sep.join(
        rf"{name}=(?P<{name}>[^{sep}]+)"
        for name in field_keys
    ) + ','
    pattern = re.compile(pattern_str)
    print(pattern_str)
    field_vals = pattern.findall(s)

    return field_vals


def find_missing_ranges(
    expected_days: pd.DatetimeIndex,
    present_days: pd.DatetimeIndex,
):
    """
    Given expected trading days and the days present in the data, return a list of
    missing contiguous ranges (start_date, end_date).

    Both inputs should be normalized DatetimeIndex objects.
    """
    if expected_days.empty:
        return []

    present_set = set(present_days)
    missing = [d for d in expected_days if d not in present_set]

    if not missing:
        return []

    pos = {d: i for i, d in enumerate(expected_days)}    

    missing.sort()
    ranges: List[Tuple[pd.Timestamp, pd.Timestamp]] = []

    start = prev = missing[0]
    for d in missing[1:]:
        # If the gap is more than 1 day, we start a new range
        if pos[d] - pos[prev] > 1:
            ranges.append((start, prev))
            start = d
        prev = d
        
    ranges.append((start, prev))

    return ranges

calendar_map = {'ARCX.PILLAR':'XNYS',
                'IFLL.IMPACT':'XLON',
                'XEUR.EOBI':'EUREX',
                'XNAS.BASIC':'XNYS',
                'XNAS.ITCH':'XNYS',
                'XNYS.PILLAR':'XNYS',
                'GLBX.MDP3':'us_futures',
}

partition_path = '../data/raw/adrs/bbo-1m/by_exchange/'
datasets = ['ARCX.PILLAR','XNAS.ITCH','XNYS.PILLAR']
dataset_partition_name = 'exchange'
tickers = ['AZN','BP','GSK','AEG','SHEL','WPP','HLN']
start_date = '2019-12-15'
end_date = pd.Timestamp.today().strftime('%Y-%m-%d')

new_datasets = []
existing_datasets = []
for dataset in datasets:
    dataset_path = os.path.join(partition_path, f"{dataset_partition_name}={dataset}")
    if os.path.exists(dataset_path) and len(os.listdir(dataset_path)) > 0:
        existing_datasets.append(dataset)
    else:
        new_datasets.append(dataset)

batch_jobs = []
if len(new_datasets) > 0:
    batch_jobs.append({
        'datasets': new_datasets,
        'tickers': tickers,
        'start_date': start_date,
        'end_date': end_date,
    })

new_tickers = []
existing_tickers = []
for ticker in tickers:
    ticker_paths = (glob(os.path.join(partition_path, f"*={ticker}*")) + 
                    glob(os.path.join(partition_path, '*', f"*={ticker}*")))
    if len(ticker_paths) > 0:
        existing_tickers.append(ticker)
    else:
        new_tickers.append(ticker)

if len(new_tickers) > 0:
    batch_jobs.append({
        'datasets': datasets,
        'tickers': new_tickers,
        'start_date': start_date,
        'end_date': end_date,
    })

if len(existing_datasets) > 0 and len(existing_tickers) > 0:
    field_keys = get_partition_field_keys(partition_path)
    field_vals = get_partition_field_vals(partition_path, field_keys=field_keys)
    if 'date' in field_keys:
        partition_df = pd.DataFrame(field_vals, columns=field_keys)

    df = pd.DataFrame(field_vals, columns=field_keys)
    all_range_df = []
    if 'date' in field_keys:
        iterator = df.groupby(['exchange','ticker'])['date']
    else:
        iterator = field_vals

    trading_days_by_calendar = {}
    for dataset in datasets:
        calendar_name = calendar_map[dataset]
        cbday = utils.get_market_business_days(calendar_name)
        trading_days_by_calendar[dataset] = pd.date_range(start_date,
                                                            end_date,
                                                            freq=cbday
                                                        )
    if 'ticker' in field_keys:
        symbol_idx = field_keys.index('ticker')
    elif 'code' in field_keys:
        symbol_idx = field_keys.index('code')
    else:
        raise ValueError("No ticker or code field found in partition keys.")

    for x in iterator:
        if 'date' in field_keys:
            comb, present_dates = x
            present_dates = pd.to_datetime(present_dates).tolist()
            field_cols = field_keys[:-1]
        else:
            comb = x
            d = [f"{key}={val}" for key,val in zip(field_keys,comb)]
            comb_path = os.path.join(partition_path, *d)
            present_dates = pd.to_datetime(pd.read_parquet(comb_path, columns=['date'],)['date'].unique()).tolist()
            field_cols = field_keys

        if comb[symbol_idx] not in tickers:
            continue
        
        if dataset_partition_name in field_keys:
            dataset = comb[0]
        else:
            if len(datasets) > 1:
                raise ValueError("Dataset partition name not in field keys but multiple datasets were given.")
            dataset = datasets[0]

        trading_days = trading_days_by_calendar[dataset]
        missing_ranges = find_missing_ranges(trading_days,
                                            present_dates)
        range_df = pd.DataFrame([comb + r for r in missing_ranges],
                    columns=field_cols + ['missing_start','missing_end'])
        all_range_df.append(range_df)

    missing_df = pd.concat(all_range_df, ignore_index=True)
    k = 0
    for (start_date, end_date), group in missing_df.groupby(['missing_start','missing_end']):
        grouped_requests = rectangular_groups(group, mode="auto")
        for datasets, tickers in grouped_requests:
            batch_jobs.append({
                'datasets': datasets,
                'tickers': tickers,
                'start_date': start_date,
                'end_date': end_date,
            })

# %%
ticker = 'AZN'

ticker_paths
# Out:
# ['../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=AZN',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=ARCX.PILLAR/ticker=AZN',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNYS.PILLAR/ticker=AZN']

# %%
ticker_paths
# Out:
# ['../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=AZN',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=ARCX.PILLAR/ticker=AZN',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNYS.PILLAR/ticker=AZN']

# %%
groups = rectangular_groups(missing_df, mode="auto")

# %%
df = pd.DataFrame({
    'exchange': ['ARCX.PILLAR', 'ARCX.PILLAR', 'XNAS.ITCH', 'XNAS.ITCH', 'XNYS.PILLAR'],
    'ticker': ['AZN', 'BP', 'AZN', 'BP', 'AZN'],
})

groups = rectangular_groups(df, mode="auto")

# %%
# Out:
# [(['ARCX.PILLAR', 'XNAS.ITCH', 'XNYS.PILLAR'], ['AZN']),
#  (['ARCX.PILLAR', 'XNAS.ITCH'], ['BP'])]

# %%
partition_df = pd.DataFrame(field_vals,columns=field_keys)
partition_df[dataset_partition_name].unique()
# Out:
# array(['XNAS.ITCH', 'ARCX.PILLAR', 'XNYS.PILLAR'], dtype=object)

# %%
cbday = utils.get_market_business_days(calendar_map[comb[0]])

# %%
cbday = utils.get_market_business_days('XNYS')
trading_days = pd.date_range('2019-12-15', 
                            pd.Timestamp.today().strftime('%Y-%m-%d'),
                            freq=cbday)
# Out:
# Empty DataFrame
# Columns: [exchange, ticker, missing_start, missing_end]
# Index: []

# %%
missing_df[missing_df['exchange']=='ARCX.PILLAR'][['missing_start','missing_end']].value_counts()
# Out:
# missing_start  missing_end
# 2019-12-16     2019-12-31     48
# 2025-11-10     2025-12-02     20
# 2025-11-03     2025-12-02     18
# 2025-09-15     2025-12-02     17
# 2020-08-12     2020-08-12      8
# 2020-08-25     2020-09-24      8
# 2022-11-21     2022-11-21      3
# 2022-11-23     2022-11-23      3
# 2022-11-22     2022-11-23      2
# 2022-12-01     2022-12-02      2
# 2022-12-08     2022-12-09      2
# 2022-12-06     2022-12-08      2
# 2022-12-02     2022-12-02      1
#                2022-12-05      1
#                2022-12-09      1
# 2019-12-16     2021-03-31      1
# 2022-12-05     2022-12-05      1
#                2022-12-06      1
# 2022-12-06     2022-12-06      1
# 2022-11-29     2022-12-06      1
# 2022-12-07     2022-12-07      1
# 2022-12-09     2022-12-09      1
# 2022-12-01     2022-12-01      1
# 2022-11-28     2022-11-29      1
# 2022-11-29     2022-11-29      1
# 2022-11-28     2022-12-08      1
# 2019-12-16     2021-06-10      1
#                2020-07-22      1
# 2022-11-23     2022-11-29      1
# 2022-11-21     2022-11-30      1
#                2022-11-29      1
#                2022-11-23      1
# 2022-08-30     2022-08-31      1
# 2022-07-19     2022-07-21      1
# 2019-12-16     2022-10-11      1
#                2022-07-21      1
#                2022-06-01      1
#                2022-01-31      1
# 2022-11-28     2022-11-28      1
# Name: count, dtype: int64

# %%
missing_df[['missing_start','missing_end']].value_counts()
# Out:
# missing_start  missing_end
# 2019-12-16     2019-12-31     48
# 2025-11-10     2025-12-02     20
# 2025-11-03     2025-12-02     18
# 2025-09-15     2025-12-02     17
# 2020-08-12     2020-08-12      8
# 2020-08-25     2020-09-24      8
# 2022-11-21     2022-11-21      3
# 2022-11-23     2022-11-23      3
# 2022-11-22     2022-11-23      2
# 2022-12-01     2022-12-02      2
# 2022-12-08     2022-12-09      2
# 2022-12-06     2022-12-08      2
# 2022-12-02     2022-12-02      1
#                2022-12-05      1
#                2022-12-09      1
# 2019-12-16     2021-03-31      1
# 2022-12-05     2022-12-05      1
#                2022-12-06      1
# 2022-12-06     2022-12-06      1
# 2022-11-29     2022-12-06      1
# 2022-12-07     2022-12-07      1
# 2022-12-09     2022-12-09      1
# 2022-12-01     2022-12-01      1
# 2022-11-28     2022-11-29      1
# 2022-11-29     2022-11-29      1
# 2022-11-28     2022-12-08      1
# 2019-12-16     2021-06-10      1
#                2020-07-22      1
# 2022-11-23     2022-11-29      1
# 2022-11-21     2022-11-30      1
#                2022-11-29      1
#                2022-11-23      1
# 2022-08-30     2022-08-31      1
# 2022-07-19     2022-07-21      1
# 2019-12-16     2022-10-11      1
#                2022-07-21      1
#                2022-06-01      1
#                2022-01-31      1
# 2022-11-28     2022-11-28      1
# Name: count, dtype: int64

# %%
present_dates
# Out:
# ['2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-02',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  '2020-01-03',
#  ...]

# %%
# Out:
# exchange     ticker
# ARCX.PILLAR  AEG       2
#              ARGX      9
#              ASML      7
#              AZN       6
#              BBVA      2
#                       ..
# XNYS.PILLAR  TTE       2
#              UL        2
#              VOD       2
#              WDS       2
#              WPP       2
# Length: 168, dtype: int64

# %%
pattern = re.compile(''.join([rf"{sep}(?P<{name}>[^/=]+)=" for name in field_names]))
pattern.search('../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-01-11')

# %%
s[:100]
# Out:
# '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-01-11,../data/raw/adrs/b'

# %%
sep = re.escape(os.sep)  # cross-platform

field_names = ["exchange", "ticker", "date"]

# /exchange=(?P<exchange>[^/]+)/ticker=(?P<ticker>[^/]+)/date=(?P<date>[^/]+)
pattern_str = sep.join(
    rf"{name}=(?P<{name}>[^{sep}]+)"
    for name in field_names
) + ','
pattern = re.compile(pattern_str)

glob_str = os.path.join('../data/raw/adrs/bbo-1m/by_exchange/', *('*',)*len(field_keys))
s = ','.join(glob(glob_str))
#s = "../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-01-11"

pattern.findall(s)
# Out:
# [('XNAS.ITCH', 'SAP', '2022-01-11'),
#  ('XNAS.ITCH', 'SAP', '2025-02-28'),
#  ('XNAS.ITCH', 'SAP', '2024-08-29'),
#  ('XNAS.ITCH', 'SAP', '2022-08-01'),
#  ('XNAS.ITCH', 'SAP', '2023-01-24'),
#  ('XNAS.ITCH', 'SAP', '2025-08-07'),
#  ('XNAS.ITCH', 'SAP', '2022-04-18'),
#  ('XNAS.ITCH', 'SAP', '2024-01-19'),
#  ('XNAS.ITCH', 'SAP', '2021-11-24'),
#  ('XNAS.ITCH', 'SAP', '2022-09-02'),
#  ('XNAS.ITCH', 'SAP', '2021-02-03'),
#  ('XNAS.ITCH', 'SAP', '2021-09-02'),
#  ('XNAS.ITCH', 'SAP', '2025-10-02'),
#  ('XNAS.ITCH', 'SAP', '2025-03-06'),
#  ('XNAS.ITCH', 'SAP', '2021-08-27'),
#  ('XNAS.ITCH', 'SAP', '2023-02-02'),
#  ('XNAS.ITCH', 'SAP', '2025-07-17'),
#  ('XNAS.ITCH', 'SAP', '2024-10-17'),
#  ('XNAS.ITCH', 'SAP', '2021-08-02'),
#  ('XNAS.ITCH', 'SAP', '2024-07-02'),
#  ('XNAS.ITCH', 'SAP', '2024-04-03'),
#  ('XNAS.ITCH', 'SAP', '2020-12-21'),
#  ('XNAS.ITCH', 'SAP', '2020-08-13'),
#  ('XNAS.ITCH', 'SAP', '2020-01-22'),
#  ('XNAS.ITCH', 'SAP', '2024-02-15'),
#  ('XNAS.ITCH', 'SAP', '2020-05-07'),
#  ('XNAS.ITCH', 'SAP', '2025-05-14'),
#  ('XNAS.ITCH', 'SAP', '2022-08-19'),
#  ('XNAS.ITCH', 'SAP', '2025-02-07'),
#  ('XNAS.ITCH', 'SAP', '2022-02-18'),
#  ('XNAS.ITCH', 'SAP', '2025-01-22'),
#  ('XNAS.ITCH', 'SAP', '2022-04-05'),
#  ('XNAS.ITCH', 'SAP', '2020-03-18'),
#  ('XNAS.ITCH', 'SAP', '2020-09-10'),
#  ('XNAS.ITCH', 'SAP', '2024-08-06'),
#  ('XNAS.ITCH', 'SAP', '2024-02-12'),
#  ('XNAS.ITCH', 'SAP', '2024-11-18'),
#  ('XNAS.ITCH', 'SAP', '2023-08-16'),
#  ('XNAS.ITCH', 'SAP', '2021-11-05'),
#  ('XNAS.ITCH', 'SAP', '2024-10-14'),
#  ('XNAS.ITCH', 'SAP', '2022-09-13'),
#  ('XNAS.ITCH', 'SAP', '2023-06-23'),
#  ('XNAS.ITCH', 'SAP', '2024-01-09'),
#  ('XNAS.ITCH', 'SAP', '2022-12-02'),
#  ('XNAS.ITCH', 'SAP', '2020-09-02'),
#  ('XNAS.ITCH', 'SAP', '2024-01-04'),
#  ('XNAS.ITCH', 'SAP', '2020-01-23'),
#  ('XNAS.ITCH', 'SAP', '2023-02-24'),
#  ('XNAS.ITCH', 'SAP', '2025-01-16'),
#  ('XNAS.ITCH', 'SAP', '2024-12-06'),
#  ('XNAS.ITCH', 'SAP', '2025-01-24'),
#  ('XNAS.ITCH', 'SAP', '2021-03-29'),
#  ('XNAS.ITCH', 'SAP', '2022-12-07'),
#  ('XNAS.ITCH', 'SAP', '2024-10-23'),
#  ('XNAS.ITCH', 'SAP', '2022-08-25'),
#  ('XNAS.ITCH', 'SAP', '2023-11-01'),
#  ('XNAS.ITCH', 'SAP', '2022-07-29'),
#  ('XNAS.ITCH', 'SAP', '2020-06-01'),
#  ('XNAS.ITCH', 'SAP', '2023-12-27'),
#  ('XNAS.ITCH', 'SAP', '2022-09-15'),
#  ('XNAS.ITCH', 'SAP', '2025-01-03'),
#  ('XNAS.ITCH', 'SAP', '2022-01-26'),
#  ('XNAS.ITCH', 'SAP', '2023-08-28'),
#  ('XNAS.ITCH', 'SAP', '2022-01-24'),
#  ('XNAS.ITCH', 'SAP', '2021-01-22'),
#  ('XNAS.ITCH', 'SAP', '2021-01-07'),
#  ('XNAS.ITCH', 'SAP', '2022-02-03'),
#  ('XNAS.ITCH', 'SAP', '2020-05-15'),
#  ('XNAS.ITCH', 'SAP', '2025-06-06'),
#  ('XNAS.ITCH', 'SAP', '2021-11-08'),
#  ('XNAS.ITCH', 'SAP', '2022-10-25'),
#  ('XNAS.ITCH', 'SAP', '2020-06-30'),
#  ('XNAS.ITCH', 'SAP', '2024-05-07'),
#  ('XNAS.ITCH', 'SAP', '2023-12-15'),
#  ('XNAS.ITCH', 'SAP', '2020-07-15'),
#  ('XNAS.ITCH', 'SAP', '2025-08-13'),
#  ('XNAS.ITCH', 'SAP', '2021-05-11'),
#  ('XNAS.ITCH', 'SAP', '2024-06-24'),
#  ('XNAS.ITCH', 'SAP', '2020-06-26'),
#  ('XNAS.ITCH', 'SAP', '2025-04-02'),
#  ('XNAS.ITCH', 'SAP', '2021-10-11'),
#  ('XNAS.ITCH', 'SAP', '2024-01-25'),
#  ('XNAS.ITCH', 'SAP', '2024-06-14'),
#  ('XNAS.ITCH', 'SAP', '2022-03-31'),
#  ('XNAS.ITCH', 'SAP', '2022-10-05'),
#  ('XNAS.ITCH', 'SAP', '2025-08-14'),
#  ('XNAS.ITCH', 'SAP', '2025-10-07'),
#  ('XNAS.ITCH', 'SAP', '2021-06-30'),
#  ('XNAS.ITCH', 'SAP', '2025-05-08'),
#  ('XNAS.ITCH', 'SAP', '2025-03-26'),
#  ('XNAS.ITCH', 'SAP', '2020-01-17'),
#  ('XNAS.ITCH', 'SAP', '2024-12-24'),
#  ('XNAS.ITCH', 'SAP', '2023-02-21'),
#  ('XNAS.ITCH', 'SAP', '2024-06-21'),
#  ('XNAS.ITCH', 'SAP', '2024-08-05'),
#  ('XNAS.ITCH', 'SAP', '2020-11-30'),
#  ('XNAS.ITCH', 'SAP', '2021-08-05'),
#  ('XNAS.ITCH', 'SAP', '2020-07-14'),
#  ('XNAS.ITCH', 'SAP', '2024-06-05'),
#  ('XNAS.ITCH', 'SAP', '2025-07-15'),
#  ('XNAS.ITCH', 'SAP', '2022-11-29'),
#  ('XNAS.ITCH', 'SAP', '2020-02-10'),
#  ('XNAS.ITCH', 'SAP', '2024-01-30'),
#  ('XNAS.ITCH', 'SAP', '2020-04-15'),
#  ('XNAS.ITCH', 'SAP', '2021-01-06'),
#  ('XNAS.ITCH', 'SAP', '2025-05-29'),
#  ('XNAS.ITCH', 'SAP', '2023-05-26'),
#  ('XNAS.ITCH', 'SAP', '2025-07-03'),
#  ('XNAS.ITCH', 'SAP', '2024-06-18'),
#  ('XNAS.ITCH', 'SAP', '2020-07-29'),
#  ('XNAS.ITCH', 'SAP', '2024-03-14'),
#  ('XNAS.ITCH', 'SAP', '2024-11-25'),
#  ('XNAS.ITCH', 'SAP', '2023-04-03'),
#  ('XNAS.ITCH', 'SAP', '2025-09-05'),
#  ('XNAS.ITCH', 'SAP', '2025-04-23'),
#  ('XNAS.ITCH', 'SAP', '2024-06-06'),
#  ('XNAS.ITCH', 'SAP', '2021-09-30'),
#  ('XNAS.ITCH', 'SAP', '2021-12-16'),
#  ('XNAS.ITCH', 'SAP', '2025-07-16'),
#  ('XNAS.ITCH', 'SAP', '2023-04-27'),
#  ('XNAS.ITCH', 'SAP', '2022-04-21'),
#  ('XNAS.ITCH', 'SAP', '2020-05-01'),
#  ('XNAS.ITCH', 'SAP', '2024-03-08'),
#  ('XNAS.ITCH', 'SAP', '2020-06-22'),
#  ('XNAS.ITCH', 'SAP', '2023-01-11'),
#  ('XNAS.ITCH', 'SAP', '2021-04-29'),
#  ('XNAS.ITCH', 'SAP', '2020-09-09'),
#  ('XNAS.ITCH', 'SAP', '2024-12-30'),
#  ('XNAS.ITCH', 'SAP', '2020-10-22'),
#  ('XNAS.ITCH', 'SAP', '2024-08-19'),
#  ('XNAS.ITCH', 'SAP', '2022-08-12'),
#  ('XNAS.ITCH', 'SAP', '2021-12-30'),
#  ('XNAS.ITCH', 'SAP', '2020-06-17'),
#  ('XNAS.ITCH', 'SAP', '2024-05-13'),
#  ('XNAS.ITCH', 'SAP', '2023-08-21'),
#  ('XNAS.ITCH', 'SAP', '2021-04-20'),
#  ('XNAS.ITCH', 'SAP', '2020-01-27'),
#  ('XNAS.ITCH', 'SAP', '2022-12-05'),
#  ('XNAS.ITCH', 'SAP', '2024-09-04'),
#  ('XNAS.ITCH', 'SAP', '2023-05-09'),
#  ('XNAS.ITCH', 'SAP', '2022-06-03'),
#  ('XNAS.ITCH', 'SAP', '2023-07-18'),
#  ('XNAS.ITCH', 'SAP', '2022-04-07'),
#  ('XNAS.ITCH', 'SAP', '2020-09-14'),
#  ('XNAS.ITCH', 'SAP', '2023-06-13'),
#  ('XNAS.ITCH', 'SAP', '2025-05-12'),
#  ('XNAS.ITCH', 'SAP', '2024-09-13'),
#  ('XNAS.ITCH', 'SAP', '2023-09-20'),
#  ('XNAS.ITCH', 'SAP', '2021-05-03'),
#  ('XNAS.ITCH', 'SAP', '2023-09-15'),
#  ('XNAS.ITCH', 'SAP', '2021-04-27'),
#  ('XNAS.ITCH', 'SAP', '2023-05-22'),
#  ('XNAS.ITCH', 'SAP', '2023-01-06'),
#  ('XNAS.ITCH', 'SAP', '2025-09-29'),
#  ('XNAS.ITCH', 'SAP', '2022-06-02'),
#  ('XNAS.ITCH', 'SAP', '2020-06-04'),
#  ('XNAS.ITCH', 'SAP', '2022-05-26'),
#  ('XNAS.ITCH', 'SAP', '2024-12-16'),
#  ('XNAS.ITCH', 'SAP', '2024-03-22'),
#  ('XNAS.ITCH', 'SAP', '2023-05-02'),
#  ('XNAS.ITCH', 'SAP', '2022-09-12'),
#  ('XNAS.ITCH', 'SAP', '2022-05-05'),
#  ('XNAS.ITCH', 'SAP', '2022-06-30'),
#  ('XNAS.ITCH', 'SAP', '2021-09-23'),
#  ('XNAS.ITCH', 'SAP', '2021-11-30'),
#  ('XNAS.ITCH', 'SAP', '2025-03-11'),
#  ('XNAS.ITCH', 'SAP', '2021-06-16'),
#  ('XNAS.ITCH', 'SAP', '2023-12-19'),
#  ('XNAS.ITCH', 'SAP', '2020-01-21'),
#  ('XNAS.ITCH', 'SAP', '2021-01-14'),
#  ('XNAS.ITCH', 'SAP', '2020-01-16'),
#  ('XNAS.ITCH', 'SAP', '2023-06-26'),
#  ('XNAS.ITCH', 'SAP', '2021-05-17'),
#  ('XNAS.ITCH', 'SAP', '2023-01-20'),
#  ('XNAS.ITCH', 'SAP', '2020-04-13'),
#  ('XNAS.ITCH', 'SAP', '2024-11-22'),
#  ('XNAS.ITCH', 'SAP', '2022-04-12'),
#  ('XNAS.ITCH', 'SAP', '2022-11-16'),
#  ('XNAS.ITCH', 'SAP', '2022-11-17'),
#  ('XNAS.ITCH', 'SAP', '2025-09-10'),
#  ('XNAS.ITCH', 'SAP', '2024-11-12'),
#  ('XNAS.ITCH', 'SAP', '2022-04-14'),
#  ('XNAS.ITCH', 'SAP', '2025-06-18'),
#  ('XNAS.ITCH', 'SAP', '2022-06-01'),
#  ('XNAS.ITCH', 'SAP', '2023-02-06'),
#  ('XNAS.ITCH', 'SAP', '2024-03-05'),
#  ('XNAS.ITCH', 'SAP', '2021-08-04'),
#  ('XNAS.ITCH', 'SAP', '2025-01-13'),
#  ('XNAS.ITCH', 'SAP', '2022-10-10'),
#  ('XNAS.ITCH', 'SAP', '2021-08-10'),
#  ('XNAS.ITCH', 'SAP', '2023-04-10'),
#  ('XNAS.ITCH', 'SAP', '2020-06-19'),
#  ('XNAS.ITCH', 'SAP', '2023-06-22'),
#  ('XNAS.ITCH', 'SAP', '2020-07-17'),
#  ('XNAS.ITCH', 'SAP', '2022-08-04'),
#  ('XNAS.ITCH', 'SAP', '2022-04-27'),
#  ('XNAS.ITCH', 'SAP', '2022-02-08'),
#  ('XNAS.ITCH', 'SAP', '2022-06-17'),
#  ('XNAS.ITCH', 'SAP', '2023-02-14'),
#  ('XNAS.ITCH', 'SAP', '2025-03-04'),
#  ('XNAS.ITCH', 'SAP', '2025-09-18'),
#  ('XNAS.ITCH', 'SAP', '2022-12-14'),
#  ('XNAS.ITCH', 'SAP', '2024-03-27'),
#  ('XNAS.ITCH', 'SAP', '2021-12-03'),
#  ('XNAS.ITCH', 'SAP', '2024-11-21'),
#  ('XNAS.ITCH', 'SAP', '2023-10-03'),
#  ('XNAS.ITCH', 'SAP', '2022-03-15'),
#  ('XNAS.ITCH', 'SAP', '2023-08-18'),
#  ('XNAS.ITCH', 'SAP', '2025-07-07'),
#  ('XNAS.ITCH', 'SAP', '2020-01-24'),
#  ('XNAS.ITCH', 'SAP', '2024-02-27'),
#  ('XNAS.ITCH', 'SAP', '2021-07-08'),
#  ('XNAS.ITCH', 'SAP', '2020-04-07'),
#  ('XNAS.ITCH', 'SAP', '2020-12-09'),
#  ('XNAS.ITCH', 'SAP', '2025-09-16'),
#  ('XNAS.ITCH', 'SAP', '2023-10-20'),
#  ('XNAS.ITCH', 'SAP', '2025-05-16'),
#  ('XNAS.ITCH', 'SAP', '2022-03-02'),
#  ('XNAS.ITCH', 'SAP', '2025-10-01'),
#  ('XNAS.ITCH', 'SAP', '2023-10-06'),
#  ('XNAS.ITCH', 'SAP', '2023-03-30'),
#  ('XNAS.ITCH', 'SAP', '2024-01-08'),
#  ('XNAS.ITCH', 'SAP', '2023-08-07'),
#  ('XNAS.ITCH', 'SAP', '2025-06-11'),
#  ('XNAS.ITCH', 'SAP', '2024-04-01'),
#  ('XNAS.ITCH', 'SAP', '2023-05-30'),
#  ('XNAS.ITCH', 'SAP', '2020-12-10'),
#  ('XNAS.ITCH', 'SAP', '2021-08-26'),
#  ('XNAS.ITCH', 'SAP', '2020-01-07'),
#  ('XNAS.ITCH', 'SAP', '2022-08-09'),
#  ('XNAS.ITCH', 'SAP', '2023-03-02'),
#  ('XNAS.ITCH', 'SAP', '2023-01-30'),
#  ('XNAS.ITCH', 'SAP', '2021-01-05'),
#  ('XNAS.ITCH', 'SAP', '2025-04-04'),
#  ('XNAS.ITCH', 'SAP', '2023-03-15'),
#  ('XNAS.ITCH', 'SAP', '2021-04-23'),
#  ('XNAS.ITCH', 'SAP', '2022-11-28'),
#  ('XNAS.ITCH', 'SAP', '2022-10-03'),
#  ('XNAS.ITCH', 'SAP', '2022-08-18'),
#  ('XNAS.ITCH', 'SAP', '2024-06-12'),
#  ('XNAS.ITCH', 'SAP', '2025-05-01'),
#  ('XNAS.ITCH', 'SAP', '2020-09-08'),
#  ('XNAS.ITCH', 'SAP', '2025-09-03'),
#  ('XNAS.ITCH', 'SAP', '2020-04-14'),
#  ('XNAS.ITCH', 'SAP', '2025-05-06'),
#  ('XNAS.ITCH', 'SAP', '2020-11-16'),
#  ('XNAS.ITCH', 'SAP', '2025-05-23'),
#  ('XNAS.ITCH', 'SAP', '2024-05-23'),
#  ('XNAS.ITCH', 'SAP', '2024-09-25'),
#  ('XNAS.ITCH', 'SAP', '2020-05-21'),
#  ('XNAS.ITCH', 'SAP', '2020-09-04'),
#  ('XNAS.ITCH', 'SAP', '2021-05-28'),
#  ('XNAS.ITCH', 'SAP', '2024-08-01'),
#  ('XNAS.ITCH', 'SAP', '2023-01-05'),
#  ('XNAS.ITCH', 'SAP', '2023-03-09'),
#  ('XNAS.ITCH', 'SAP', '2021-07-20'),
#  ('XNAS.ITCH', 'SAP', '2023-05-01'),
#  ('XNAS.ITCH', 'SAP', '2025-04-15'),
#  ('XNAS.ITCH', 'SAP', '2022-01-05'),
#  ('XNAS.ITCH', 'SAP', '2023-03-21'),
#  ('XNAS.ITCH', 'SAP', '2023-02-23'),
#  ('XNAS.ITCH', 'SAP', '2022-10-04'),
#  ('XNAS.ITCH', 'SAP', '2020-07-10'),
#  ('XNAS.ITCH', 'SAP', '2022-05-18'),
#  ('XNAS.ITCH', 'SAP', '2020-01-13'),
#  ('XNAS.ITCH', 'SAP', '2021-03-01'),
#  ('XNAS.ITCH', 'SAP', '2022-08-03'),
#  ('XNAS.ITCH', 'SAP', '2025-07-25'),
#  ('XNAS.ITCH', 'SAP', '2024-07-18'),
#  ('XNAS.ITCH', 'SAP', '2022-11-04'),
#  ('XNAS.ITCH', 'SAP', '2020-12-28'),
#  ('XNAS.ITCH', 'SAP', '2022-05-12'),
#  ('XNAS.ITCH', 'SAP', '2023-12-29'),
#  ('XNAS.ITCH', 'SAP', '2020-09-18'),
#  ('XNAS.ITCH', 'SAP', '2020-07-30'),
#  ('XNAS.ITCH', 'SAP', '2021-06-07'),
#  ('XNAS.ITCH', 'SAP', '2022-04-08'),
#  ('XNAS.ITCH', 'SAP', '2025-10-24'),
#  ('XNAS.ITCH', 'SAP', '2022-10-27'),
#  ('XNAS.ITCH', 'SAP', '2025-06-20'),
#  ('XNAS.ITCH', 'SAP', '2020-07-22'),
#  ('XNAS.ITCH', 'SAP', '2023-08-09'),
#  ('XNAS.ITCH', 'SAP', '2024-07-16'),
#  ('XNAS.ITCH', 'SAP', '2025-08-04'),
#  ('XNAS.ITCH', 'SAP', '2020-06-08'),
#  ('XNAS.ITCH', 'SAP', '2020-12-08'),
#  ('XNAS.ITCH', 'SAP', '2021-12-20'),
#  ('XNAS.ITCH', 'SAP', '2020-04-27'),
#  ('XNAS.ITCH', 'SAP', '2024-06-11'),
#  ('XNAS.ITCH', 'SAP', '2024-12-27'),
#  ('XNAS.ITCH', 'SAP', '2025-01-17'),
#  ('XNAS.ITCH', 'SAP', '2020-02-28'),
#  ('XNAS.ITCH', 'SAP', '2021-01-20'),
#  ('XNAS.ITCH', 'SAP', '2024-08-07'),
#  ('XNAS.ITCH', 'SAP', '2023-10-12'),
#  ('XNAS.ITCH', 'SAP', '2025-10-27'),
#  ('XNAS.ITCH', 'SAP', '2024-12-03'),
#  ('XNAS.ITCH', 'SAP', '2020-01-31'),
#  ('XNAS.ITCH', 'SAP', '2025-08-15'),
#  ('XNAS.ITCH', 'SAP', '2020-01-15'),
#  ('XNAS.ITCH', 'SAP', '2024-04-17'),
#  ('XNAS.ITCH', 'SAP', '2022-04-28'),
#  ('XNAS.ITCH', 'SAP', '2020-12-31'),
#  ('XNAS.ITCH', 'SAP', '2024-07-25'),
#  ('XNAS.ITCH', 'SAP', '2022-03-29'),
#  ('XNAS.ITCH', 'SAP', '2024-04-29'),
#  ('XNAS.ITCH', 'SAP', '2020-05-27'),
#  ('XNAS.ITCH', 'SAP', '2025-07-18'),
#  ('XNAS.ITCH', 'SAP', '2023-12-20'),
#  ('XNAS.ITCH', 'SAP', '2022-07-22'),
#  ('XNAS.ITCH', 'SAP', '2024-04-02'),
#  ('XNAS.ITCH', 'SAP', '2024-09-10'),
#  ('XNAS.ITCH', 'SAP', '2023-12-06'),
#  ('XNAS.ITCH', 'SAP', '2025-07-29'),
#  ('XNAS.ITCH', 'SAP', '2024-04-23'),
#  ('XNAS.ITCH', 'SAP', '2023-11-07'),
#  ('XNAS.ITCH', 'SAP', '2025-05-21'),
#  ('XNAS.ITCH', 'SAP', '2024-05-01'),
#  ('XNAS.ITCH', 'SAP', '2024-09-24'),
#  ('XNAS.ITCH', 'SAP', '2024-08-26'),
#  ('XNAS.ITCH', 'SAP', '2022-05-02'),
#  ('XNAS.ITCH', 'SAP', '2023-04-13'),
#  ('XNAS.ITCH', 'SAP', '2024-04-09'),
#  ('XNAS.ITCH', 'SAP', '2021-11-16'),
#  ('XNAS.ITCH', 'SAP', '2024-06-26'),
#  ('XNAS.ITCH', 'SAP', '2021-08-06'),
#  ('XNAS.ITCH', 'SAP', '2021-05-21'),
#  ('XNAS.ITCH', 'SAP', '2025-07-21'),
#  ('XNAS.ITCH', 'SAP', '2024-06-28'),
#  ('XNAS.ITCH', 'SAP', '2020-04-28'),
#  ('XNAS.ITCH', 'SAP', '2024-05-28'),
#  ('XNAS.ITCH', 'SAP', '2024-04-24'),
#  ('XNAS.ITCH', 'SAP', '2021-12-22'),
#  ('XNAS.ITCH', 'SAP', '2023-12-22'),
#  ('XNAS.ITCH', 'SAP', '2022-06-29'),
#  ('XNAS.ITCH', 'SAP', '2023-02-10'),
#  ('XNAS.ITCH', 'SAP', '2021-12-10'),
#  ('XNAS.ITCH', 'SAP', '2024-09-27'),
#  ('XNAS.ITCH', 'SAP', '2021-08-03'),
#  ('XNAS.ITCH', 'SAP', '2022-01-18'),
#  ('XNAS.ITCH', 'SAP', '2022-08-16'),
#  ('XNAS.ITCH', 'SAP', '2024-12-11'),
#  ('XNAS.ITCH', 'SAP', '2023-12-13'),
#  ('XNAS.ITCH', 'SAP', '2022-11-08'),
#  ('XNAS.ITCH', 'SAP', '2020-10-09'),
#  ('XNAS.ITCH', 'SAP', '2021-02-19'),
#  ('XNAS.ITCH', 'SAP', '2022-07-06'),
#  ('XNAS.ITCH', 'SAP', '2022-06-21'),
#  ('XNAS.ITCH', 'SAP', '2024-05-20'),
#  ('XNAS.ITCH', 'SAP', '2025-02-19'),
#  ('XNAS.ITCH', 'SAP', '2021-04-15'),
#  ('XNAS.ITCH', 'SAP', '2022-03-22'),
#  ('XNAS.ITCH', 'SAP', '2022-09-16'),
#  ('XNAS.ITCH', 'SAP', '2021-05-13'),
#  ('XNAS.ITCH', 'SAP', '2024-02-07'),
#  ('XNAS.ITCH', 'SAP', '2024-03-28'),
#  ('XNAS.ITCH', 'SAP', '2021-09-17'),
#  ('XNAS.ITCH', 'SAP', '2020-12-15'),
#  ('XNAS.ITCH', 'SAP', '2021-03-03'),
#  ('XNAS.ITCH', 'SAP', '2024-08-15'),
#  ('XNAS.ITCH', 'SAP', '2021-02-24'),
#  ('XNAS.ITCH', 'SAP', '2022-06-13'),
#  ('XNAS.ITCH', 'SAP', '2022-09-23'),
#  ('XNAS.ITCH', 'SAP', '2021-02-22'),
#  ('XNAS.ITCH', 'SAP', '2024-09-11'),
#  ('XNAS.ITCH', 'SAP', '2021-03-23'),
#  ('XNAS.ITCH', 'SAP', '2021-10-12'),
#  ('XNAS.ITCH', 'SAP', '2023-05-23'),
#  ('XNAS.ITCH', 'SAP', '2020-12-02'),
#  ('XNAS.ITCH', 'SAP', '2021-03-09'),
#  ('XNAS.ITCH', 'SAP', '2020-10-26'),
#  ('XNAS.ITCH', 'SAP', '2024-08-30'),
#  ('XNAS.ITCH', 'SAP', '2020-07-28'),
#  ('XNAS.ITCH', 'SAP', '2020-03-27'),
#  ('XNAS.ITCH', 'SAP', '2024-12-12'),
#  ('XNAS.ITCH', 'SAP', '2025-08-27'),
#  ('XNAS.ITCH', 'SAP', '2022-11-02'),
#  ('XNAS.ITCH', 'SAP', '2023-10-24'),
#  ('XNAS.ITCH', 'SAP', '2025-03-17'),
#  ('XNAS.ITCH', 'SAP', '2023-03-27'),
#  ('XNAS.ITCH', 'SAP', '2023-07-14'),
#  ('XNAS.ITCH', 'SAP', '2023-10-11'),
#  ('XNAS.ITCH', 'SAP', '2020-06-02'),
#  ('XNAS.ITCH', 'SAP', '2022-10-07'),
#  ('XNAS.ITCH', 'SAP', '2020-09-22'),
#  ('XNAS.ITCH', 'SAP', '2020-05-14'),
#  ('XNAS.ITCH', 'SAP', '2020-10-02'),
#  ('XNAS.ITCH', 'SAP', '2021-04-19'),
#  ('XNAS.ITCH', 'SAP', '2021-08-17'),
#  ('XNAS.ITCH', 'SAP', '2021-07-30'),
#  ('XNAS.ITCH', 'SAP', '2022-12-27'),
#  ('XNAS.ITCH', 'SAP', '2022-09-07'),
#  ('XNAS.ITCH', 'SAP', '2022-01-13'),
#  ('XNAS.ITCH', 'SAP', '2021-09-24'),
#  ('XNAS.ITCH', 'SAP', '2020-02-04'),
#  ('XNAS.ITCH', 'SAP', '2025-04-16'),
#  ('XNAS.ITCH', 'SAP', '2025-02-13'),
#  ('XNAS.ITCH', 'SAP', '2022-12-28'),
#  ('XNAS.ITCH', 'SAP', '2025-08-12'),
#  ('XNAS.ITCH', 'SAP', '2021-06-21'),
#  ('XNAS.ITCH', 'SAP', '2024-08-20'),
#  ('XNAS.ITCH', 'SAP', '2020-03-11'),
#  ('XNAS.ITCH', 'SAP', '2021-07-14'),
#  ('XNAS.ITCH', 'SAP', '2021-01-25'),
#  ('XNAS.ITCH', 'SAP', '2022-10-13'),
#  ('XNAS.ITCH', 'SAP', '2024-01-23'),
#  ('XNAS.ITCH', 'SAP', '2023-04-28'),
#  ('XNAS.ITCH', 'SAP', '2025-03-24'),
#  ('XNAS.ITCH', 'SAP', '2025-05-28'),
#  ('XNAS.ITCH', 'SAP', '2024-12-09'),
#  ('XNAS.ITCH', 'SAP', '2025-02-27'),
#  ('XNAS.ITCH', 'SAP', '2025-08-21'),
#  ('XNAS.ITCH', 'SAP', '2023-07-05'),
#  ('XNAS.ITCH', 'SAP', '2024-03-11'),
#  ('XNAS.ITCH', 'SAP', '2021-07-01'),
#  ('XNAS.ITCH', 'SAP', '2024-04-19'),
#  ('XNAS.ITCH', 'SAP', '2022-02-14'),
#  ('XNAS.ITCH', 'SAP', '2022-02-23'),
#  ('XNAS.ITCH', 'SAP', '2022-05-20'),
#  ('XNAS.ITCH', 'SAP', '2024-11-19'),
#  ('XNAS.ITCH', 'SAP', '2020-11-12'),
#  ('XNAS.ITCH', 'SAP', '2021-04-30'),
#  ('XNAS.ITCH', 'SAP', '2020-08-21'),
#  ('XNAS.ITCH', 'SAP', '2024-06-17'),
#  ('XNAS.ITCH', 'SAP', '2023-06-14'),
#  ('XNAS.ITCH', 'SAP', '2025-10-14'),
#  ('XNAS.ITCH', 'SAP', '2025-01-02'),
#  ('XNAS.ITCH', 'SAP', '2023-08-04'),
#  ('XNAS.ITCH', 'SAP', '2022-03-28'),
#  ('XNAS.ITCH', 'SAP', '2022-09-01'),
#  ('XNAS.ITCH', 'SAP', '2020-03-31'),
#  ('XNAS.ITCH', 'SAP', '2025-07-23'),
#  ('XNAS.ITCH', 'SAP', '2022-06-08'),
#  ('XNAS.ITCH', 'SAP', '2024-10-29'),
#  ('XNAS.ITCH', 'SAP', '2024-01-12'),
#  ('XNAS.ITCH', 'SAP', '2024-12-02'),
#  ('XNAS.ITCH', 'SAP', '2025-01-08'),
#  ('XNAS.ITCH', 'SAP', '2024-02-22'),
#  ('XNAS.ITCH', 'SAP', '2025-08-25'),
#  ('XNAS.ITCH', 'SAP', '2022-03-03'),
#  ('XNAS.ITCH', 'SAP', '2020-11-03'),
#  ('XNAS.ITCH', 'SAP', '2020-05-18'),
#  ('XNAS.ITCH', 'SAP', '2024-06-03'),
#  ('XNAS.ITCH', 'SAP', '2023-01-13'),
#  ('XNAS.ITCH', 'SAP', '2025-05-22'),
#  ('XNAS.ITCH', 'SAP', '2021-03-26'),
#  ('XNAS.ITCH', 'SAP', '2020-11-02'),
#  ('XNAS.ITCH', 'SAP', '2025-01-29'),
#  ('XNAS.ITCH', 'SAP', '2023-08-29'),
#  ('XNAS.ITCH', 'SAP', '2020-08-26'),
#  ('XNAS.ITCH', 'SAP', '2024-10-07'),
#  ('XNAS.ITCH', 'SAP', '2020-06-12'),
#  ('XNAS.ITCH', 'SAP', '2023-06-30'),
#  ('XNAS.ITCH', 'SAP', '2020-10-15'),
#  ('XNAS.ITCH', 'SAP', '2021-05-27'),
#  ('XNAS.ITCH', 'SAP', '2021-03-04'),
#  ('XNAS.ITCH', 'SAP', '2023-08-23'),
#  ('XNAS.ITCH', 'SAP', '2025-03-19'),
#  ('XNAS.ITCH', 'SAP', '2023-05-16'),
#  ('XNAS.ITCH', 'SAP', '2023-07-07'),
#  ('XNAS.ITCH', 'SAP', '2025-03-25'),
#  ('XNAS.ITCH', 'SAP', '2022-06-10'),
#  ('XNAS.ITCH', 'SAP', '2021-01-13'),
#  ('XNAS.ITCH', 'SAP', '2023-03-01'),
#  ('XNAS.ITCH', 'SAP', '2023-07-24'),
#  ('XNAS.ITCH', 'SAP', '2022-02-09'),
#  ('XNAS.ITCH', 'SAP', '2023-08-17'),
#  ('XNAS.ITCH', 'SAP', '2024-11-07'),
#  ('XNAS.ITCH', 'SAP', '2020-03-19'),
#  ('XNAS.ITCH', 'SAP', '2023-10-17'),
#  ('XNAS.ITCH', 'SAP', '2022-08-15'),
#  ('XNAS.ITCH', 'SAP', '2025-08-05'),
#  ('XNAS.ITCH', 'SAP', '2022-05-03'),
#  ('XNAS.ITCH', 'SAP', '2025-07-01'),
#  ('XNAS.ITCH', 'SAP', '2023-08-31'),
#  ('XNAS.ITCH', 'SAP', '2020-08-04'),
#  ('XNAS.ITCH', 'SAP', '2023-11-30'),
#  ('XNAS.ITCH', 'SAP', '2020-05-26'),
#  ('XNAS.ITCH', 'SAP', '2020-04-17'),
#  ('XNAS.ITCH', 'SAP', '2021-10-01'),
#  ('XNAS.ITCH', 'SAP', '2021-03-05'),
#  ('XNAS.ITCH', 'SAP', '2023-02-08'),
#  ('XNAS.ITCH', 'SAP', '2021-04-09'),
#  ('XNAS.ITCH', 'SAP', '2024-11-14'),
#  ('XNAS.ITCH', 'SAP', '2020-07-16'),
#  ('XNAS.ITCH', 'SAP', '2024-05-09'),
#  ('XNAS.ITCH', 'SAP', '2023-10-26'),
#  ('XNAS.ITCH', 'SAP', '2023-05-18'),
#  ('XNAS.ITCH', 'SAP', '2024-12-18'),
#  ('XNAS.ITCH', 'SAP', '2023-03-07'),
#  ('XNAS.ITCH', 'SAP', '2024-08-28'),
#  ('XNAS.ITCH', 'SAP', '2020-05-04'),
#  ('XNAS.ITCH', 'SAP', '2021-01-11'),
#  ('XNAS.ITCH', 'SAP', '2025-08-06'),
#  ('XNAS.ITCH', 'SAP', '2021-03-16'),
#  ('XNAS.ITCH', 'SAP', '2022-01-03'),
#  ('XNAS.ITCH', 'SAP', '2022-11-01'),
#  ('XNAS.ITCH', 'SAP', '2025-06-17'),
#  ('XNAS.ITCH', 'SAP', '2024-07-01'),
#  ('XNAS.ITCH', 'SAP', '2023-07-12'),
#  ('XNAS.ITCH', 'SAP', '2023-10-09'),
#  ('XNAS.ITCH', 'SAP', '2024-03-07'),
#  ('XNAS.ITCH', 'SAP', '2025-07-14'),
#  ('XNAS.ITCH', 'SAP', '2023-08-25'),
#  ('XNAS.ITCH', 'SAP', '2023-09-01'),
#  ('XNAS.ITCH', 'SAP', '2022-09-09'),
#  ('XNAS.ITCH', 'SAP', '2022-03-01'),
#  ('XNAS.ITCH', 'SAP', '2024-04-25'),
#  ('XNAS.ITCH', 'SAP', '2025-05-05'),
#  ('XNAS.ITCH', 'SAP', '2022-07-13'),
#  ('XNAS.ITCH', 'SAP', '2020-12-24'),
#  ('XNAS.ITCH', 'SAP', '2024-04-05'),
#  ('XNAS.ITCH', 'SAP', '2024-02-14'),
#  ('XNAS.ITCH', 'SAP', '2022-01-12'),
#  ('XNAS.ITCH', 'SAP', '2025-07-08'),
#  ('XNAS.ITCH', 'SAP', '2025-10-08'),
#  ('XNAS.ITCH', 'SAP', '2024-08-13'),
#  ('XNAS.ITCH', 'SAP', '2021-04-16'),
#  ('XNAS.ITCH', 'SAP', '2020-05-28'),
#  ('XNAS.ITCH', 'SAP', '2024-07-30'),
#  ('XNAS.ITCH', 'SAP', '2023-12-05'),
#  ('XNAS.ITCH', 'SAP', '2020-07-08'),
#  ('XNAS.ITCH', 'SAP', '2021-11-22'),
#  ('XNAS.ITCH', 'SAP', '2025-08-19'),
#  ('XNAS.ITCH', 'SAP', '2020-11-06'),
#  ('XNAS.ITCH', 'SAP', '2021-03-19'),
#  ('XNAS.ITCH', 'SAP', '2020-10-07'),
#  ('XNAS.ITCH', 'SAP', '2025-06-02'),
#  ('XNAS.ITCH', 'SAP', '2023-03-06'),
#  ('XNAS.ITCH', 'SAP', '2022-06-16'),
#  ('XNAS.ITCH', 'SAP', '2023-10-23'),
#  ('XNAS.ITCH', 'SAP', '2021-05-18'),
#  ('XNAS.ITCH', 'SAP', '2025-10-10'),
#  ('XNAS.ITCH', 'SAP', '2020-03-26'),
#  ('XNAS.ITCH', 'SAP', '2021-11-18'),
#  ('XNAS.ITCH', 'SAP', '2022-11-15'),
#  ('XNAS.ITCH', 'SAP', '2021-03-12'),
#  ('XNAS.ITCH', 'SAP', '2021-04-06'),
#  ('XNAS.ITCH', 'SAP', '2025-04-08'),
#  ('XNAS.ITCH', 'SAP', '2022-05-31'),
#  ('XNAS.ITCH', 'SAP', '2025-07-24'),
#  ('XNAS.ITCH', 'SAP', '2022-06-06'),
#  ('XNAS.ITCH', 'SAP', '2021-10-27'),
#  ('XNAS.ITCH', 'SAP', '2023-04-18'),
#  ('XNAS.ITCH', 'SAP', '2024-12-23'),
#  ('XNAS.ITCH', 'SAP', '2022-04-20'),
#  ('XNAS.ITCH', 'SAP', '2021-03-02'),
#  ('XNAS.ITCH', 'SAP', '2023-08-14'),
#  ('XNAS.ITCH', 'SAP', '2020-02-18'),
#  ('XNAS.ITCH', 'SAP', '2025-02-14'),
#  ('XNAS.ITCH', 'SAP', '2021-08-24'),
#  ('XNAS.ITCH', 'SAP', '2023-12-14'),
#  ('XNAS.ITCH', 'SAP', '2020-02-24'),
#  ('XNAS.ITCH', 'SAP', '2024-07-23'),
#  ('XNAS.ITCH', 'SAP', '2024-05-14'),
#  ('XNAS.ITCH', 'SAP', '2021-02-05'),
#  ('XNAS.ITCH', 'SAP', '2023-11-14'),
#  ('XNAS.ITCH', 'SAP', '2024-01-22'),
#  ('XNAS.ITCH', 'SAP', '2021-05-06'),
#  ('XNAS.ITCH', 'SAP', '2023-01-23'),
#  ('XNAS.ITCH', 'SAP', '2024-04-10'),
#  ('XNAS.ITCH', 'SAP', '2024-12-17'),
#  ('XNAS.ITCH', 'SAP', '2020-11-20'),
#  ('XNAS.ITCH', 'SAP', '2024-09-26'),
#  ('XNAS.ITCH', 'SAP', '2022-08-24'),
#  ('XNAS.ITCH', 'SAP', '2021-10-26'),
#  ('XNAS.ITCH', 'SAP', '2024-08-16'),
#  ('XNAS.ITCH', 'SAP', '2021-10-14'),
#  ('XNAS.ITCH', 'SAP', '2020-10-05'),
#  ('XNAS.ITCH', 'SAP', '2021-12-07'),
#  ('XNAS.ITCH', 'SAP', '2022-04-11'),
#  ('XNAS.ITCH', 'SAP', '2022-11-25'),
#  ('XNAS.ITCH', 'SAP', '2022-07-28'),
#  ('XNAS.ITCH', 'SAP', '2023-03-24'),
#  ('XNAS.ITCH', 'SAP', '2022-06-09'),
#  ('XNAS.ITCH', 'SAP', '2021-09-28'),
#  ('XNAS.ITCH', 'SAP', '2025-04-01'),
#  ('XNAS.ITCH', 'SAP', '2023-03-22'),
#  ('XNAS.ITCH', 'SAP', '2023-06-21'),
#  ('XNAS.ITCH', 'SAP', '2022-07-27'),
#  ('XNAS.ITCH', 'SAP', '2023-05-15'),
#  ('XNAS.ITCH', 'SAP', '2023-09-18'),
#  ('XNAS.ITCH', 'SAP', '2020-08-14'),
#  ('XNAS.ITCH', 'SAP', '2021-12-23'),
#  ('XNAS.ITCH', 'SAP', '2022-01-10'),
#  ('XNAS.ITCH', 'SAP', '2023-11-02'),
#  ('XNAS.ITCH', 'SAP', '2020-09-15'),
#  ('XNAS.ITCH', 'SAP', '2020-10-12'),
#  ('XNAS.ITCH', 'SAP', '2023-06-02'),
#  ('XNAS.ITCH', 'SAP', '2021-09-21'),
#  ('XNAS.ITCH', 'SAP', '2022-09-20'),
#  ('XNAS.ITCH', 'SAP', '2021-11-03'),
#  ('XNAS.ITCH', 'SAP', '2023-07-06'),
#  ('XNAS.ITCH', 'SAP', '2021-12-06'),
#  ('XNAS.ITCH', 'SAP', '2025-06-03'),
#  ('XNAS.ITCH', 'SAP', '2021-03-11'),
#  ('XNAS.ITCH', 'SAP', '2020-08-10'),
#  ('XNAS.ITCH', 'SAP', '2025-04-09'),
#  ('XNAS.ITCH', 'SAP', '2020-05-29'),
#  ('XNAS.ITCH', 'SAP', '2023-11-08'),
#  ('XNAS.ITCH', 'SAP', '2024-09-12'),
#  ('XNAS.ITCH', 'SAP', '2020-10-16'),
#  ('XNAS.ITCH', 'SAP', '2024-08-02'),
#  ('XNAS.ITCH', 'SAP', '2024-11-05'),
#  ('XNAS.ITCH', 'SAP', '2022-09-19'),
#  ('XNAS.ITCH', 'SAP', '2025-09-22'),
#  ('XNAS.ITCH', 'SAP', '2023-04-25'),
#  ('XNAS.ITCH', 'SAP', '2022-12-20'),
#  ('XNAS.ITCH', 'SAP', '2020-10-30'),
#  ('XNAS.ITCH', 'SAP', '2022-11-10'),
#  ('XNAS.ITCH', 'SAP', '2023-09-07'),
#  ('XNAS.ITCH', 'SAP', '2025-05-13'),
#  ('XNAS.ITCH', 'SAP', '2024-05-03'),
#  ('XNAS.ITCH', 'SAP', '2024-04-26'),
#  ('XNAS.ITCH', 'SAP', '2020-05-19'),
#  ('XNAS.ITCH', 'SAP', '2020-06-09'),
#  ('XNAS.ITCH', 'SAP', '2024-07-15'),
#  ('XNAS.ITCH', 'SAP', '2024-10-09'),
#  ('XNAS.ITCH', 'SAP', '2023-12-28'),
#  ('XNAS.ITCH', 'SAP', '2021-05-24'),
#  ('XNAS.ITCH', 'SAP', '2024-02-13'),
#  ('XNAS.ITCH', 'SAP', '2023-11-27'),
#  ('XNAS.ITCH', 'SAP', '2023-07-19'),
#  ('XNAS.ITCH', 'SAP', '2022-07-11'),
#  ('XNAS.ITCH', 'SAP', '2024-01-10'),
#  ('XNAS.ITCH', 'SAP', '2022-12-09'),
#  ('XNAS.ITCH', 'SAP', '2022-05-17'),
#  ('XNAS.ITCH', 'SAP', '2025-10-15'),
#  ('XNAS.ITCH', 'SAP', '2021-03-31'),
#  ('XNAS.ITCH', 'SAP', '2024-01-05'),
#  ('XNAS.ITCH', 'SAP', '2021-11-19'),
#  ('XNAS.ITCH', 'SAP', '2025-10-31'),
#  ('XNAS.ITCH', 'SAP', '2025-04-29'),
#  ('XNAS.ITCH', 'SAP', '2020-07-07'),
#  ('XNAS.ITCH', 'SAP', '2020-06-15'),
#  ('XNAS.ITCH', 'SAP', '2021-09-22'),
#  ('XNAS.ITCH', 'SAP', '2020-03-02'),
#  ('XNAS.ITCH', 'SAP', '2021-12-27'),
#  ('XNAS.ITCH', 'SAP', '2025-07-31'),
#  ('XNAS.ITCH', 'SAP', '2022-02-07'),
#  ('XNAS.ITCH', 'SAP', '2025-06-23'),
#  ('XNAS.ITCH', 'SAP', '2020-06-29'),
#  ('XNAS.ITCH', 'SAP', '2025-09-11'),
#  ('XNAS.ITCH', 'SAP', '2022-08-22'),
#  ('XNAS.ITCH', 'SAP', '2025-05-27'),
#  ('XNAS.ITCH', 'SAP', '2022-06-23'),
#  ('XNAS.ITCH', 'SAP', '2025-04-07'),
#  ('XNAS.ITCH', 'SAP', '2023-11-06'),
#  ('XNAS.ITCH', 'SAP', '2025-04-03'),
#  ('XNAS.ITCH', 'SAP', '2022-06-07'),
#  ('XNAS.ITCH', 'SAP', '2021-08-11'),
#  ('XNAS.ITCH', 'SAP', '2025-10-03'),
#  ('XNAS.ITCH', 'SAP', '2025-03-31'),
#  ('XNAS.ITCH', 'SAP', '2025-10-16'),
#  ('XNAS.ITCH', 'SAP', '2020-07-31'),
#  ('XNAS.ITCH', 'SAP', '2020-03-06'),
#  ('XNAS.ITCH', 'SAP', '2022-01-21'),
#  ('XNAS.ITCH', 'SAP', '2020-06-11'),
#  ('XNAS.ITCH', 'SAP', '2023-03-31'),
#  ('XNAS.ITCH', 'SAP', '2025-02-06'),
#  ('XNAS.ITCH', 'SAP', '2025-09-02'),
#  ('XNAS.ITCH', 'SAP', '2022-09-14'),
#  ('XNAS.ITCH', 'SAP', '2025-10-28'),
#  ('XNAS.ITCH', 'SAP', '2023-11-28'),
#  ('XNAS.ITCH', 'SAP', '2022-12-12'),
#  ('XNAS.ITCH', 'SAP', '2022-05-16'),
#  ('XNAS.ITCH', 'SAP', '2020-10-27'),
#  ('XNAS.ITCH', 'SAP', '2020-05-20'),
#  ('XNAS.ITCH', 'SAP', '2022-03-11'),
#  ('XNAS.ITCH', 'SAP', '2024-03-18'),
#  ('XNAS.ITCH', 'SAP', '2024-01-11'),
#  ('XNAS.ITCH', 'SAP', '2021-09-03'),
#  ('XNAS.ITCH', 'SAP', '2021-09-15'),
#  ('XNAS.ITCH', 'SAP', '2025-01-06'),
#  ('XNAS.ITCH', 'SAP', '2022-03-23'),
#  ('XNAS.ITCH', 'SAP', '2025-01-15'),
#  ('XNAS.ITCH', 'SAP', '2020-08-27'),
#  ('XNAS.ITCH', 'SAP', '2023-09-28'),
#  ('XNAS.ITCH', 'SAP', '2023-01-04'),
#  ('XNAS.ITCH', 'SAP', '2023-09-12'),
#  ('XNAS.ITCH', 'SAP', '2024-06-04'),
#  ('XNAS.ITCH', 'SAP', '2023-05-25'),
#  ('XNAS.ITCH', 'SAP', '2024-08-08'),
#  ('XNAS.ITCH', 'SAP', '2020-07-20'),
#  ('XNAS.ITCH', 'SAP', '2022-08-11'),
#  ('XNAS.ITCH', 'SAP', '2021-11-17'),
#  ('XNAS.ITCH', 'SAP', '2023-05-08'),
#  ('XNAS.ITCH', 'SAP', '2022-11-14'),
#  ('XNAS.ITCH', 'SAP', '2023-12-12'),
#  ('XNAS.ITCH', 'SAP', '2025-01-31'),
#  ('XNAS.ITCH', 'SAP', '2020-01-29'),
#  ('XNAS.ITCH', 'SAP', '2020-03-17'),
#  ('XNAS.ITCH', 'SAP', '2020-04-22'),
#  ('XNAS.ITCH', 'SAP', '2024-09-18'),
#  ('XNAS.ITCH', 'SAP', '2025-09-12'),
#  ('XNAS.ITCH', 'SAP', '2024-11-29'),
#  ('XNAS.ITCH', 'SAP', '2020-09-11'),
#  ('XNAS.ITCH', 'SAP', '2023-12-26'),
#  ('XNAS.ITCH', 'SAP', '2021-04-08'),
#  ('XNAS.ITCH', 'SAP', '2021-04-28'),
#  ('XNAS.ITCH', 'SAP', '2024-02-06'),
#  ('XNAS.ITCH', 'SAP', '2024-02-01'),
#  ('XNAS.ITCH', 'SAP', '2024-10-08'),
#  ('XNAS.ITCH', 'SAP', '2024-12-31'),
#  ('XNAS.ITCH', 'SAP', '2020-05-05'),
#  ('XNAS.ITCH', 'SAP', '2024-10-02'),
#  ('XNAS.ITCH', 'SAP', '2024-11-04'),
#  ('XNAS.ITCH', 'SAP', '2024-11-06'),
#  ('XNAS.ITCH', 'SAP', '2020-01-28'),
#  ('XNAS.ITCH', 'SAP', '2023-05-19'),
#  ('XNAS.ITCH', 'SAP', '2025-09-25'),
#  ('XNAS.ITCH', 'SAP', '2020-12-04'),
#  ('XNAS.ITCH', 'SAP', '2020-03-13'),
#  ('XNAS.ITCH', 'SAP', '2022-07-08'),
#  ('XNAS.ITCH', 'SAP', '2020-06-03'),
#  ('XNAS.ITCH', 'SAP', '2021-10-21'),
#  ('XNAS.ITCH', 'SAP', '2020-11-17'),
#  ('XNAS.ITCH', 'SAP', '2020-12-16'),
#  ('XNAS.ITCH', 'SAP', '2021-11-04'),
#  ('XNAS.ITCH', 'SAP', '2025-06-13'),
#  ('XNAS.ITCH', 'SAP', '2024-10-30'),
#  ('XNAS.ITCH', 'SAP', '2022-11-11'),
#  ('XNAS.ITCH', 'SAP', '2023-05-03'),
#  ('XNAS.ITCH', 'SAP', '2020-07-06'),
#  ('XNAS.ITCH', 'SAP', '2021-01-28'),
#  ('XNAS.ITCH', 'SAP', '2024-02-08'),
#  ('XNAS.ITCH', 'SAP', '2022-12-22'),
#  ('XNAS.ITCH', 'SAP', '2023-02-27'),
#  ('XNAS.ITCH', 'SAP', '2020-04-02'),
#  ('XNAS.ITCH', 'SAP', '2023-07-21'),
#  ('XNAS.ITCH', 'SAP', '2020-06-25'),
#  ('XNAS.ITCH', 'SAP', '2025-05-02'),
#  ('XNAS.ITCH', 'SAP', '2024-08-27'),
#  ('XNAS.ITCH', 'SAP', '2025-02-25'),
#  ('XNAS.ITCH', 'SAP', '2023-04-05'),
#  ('XNAS.ITCH', 'SAP', '2020-03-10'),
#  ('XNAS.ITCH', 'SAP', '2023-02-17'),
#  ('XNAS.ITCH', 'SAP', '2021-09-10'),
#  ('XNAS.ITCH', 'SAP', '2020-08-28'),
#  ('XNAS.ITCH', 'SAP', '2021-11-09'),
#  ('XNAS.ITCH', 'SAP', '2024-07-10'),
#  ('XNAS.ITCH', 'SAP', '2023-10-04'),
#  ('XNAS.ITCH', 'SAP', '2022-03-04'),
#  ('XNAS.ITCH', 'SAP', '2023-12-18'),
#  ('XNAS.ITCH', 'SAP', '2023-03-14'),
#  ('XNAS.ITCH', 'SAP', '2020-12-29'),
#  ('XNAS.ITCH', 'SAP', '2025-01-21'),
#  ('XNAS.ITCH', 'SAP', '2022-01-28'),
#  ('XNAS.ITCH', 'SAP', '2025-06-05'),
#  ('XNAS.ITCH', 'SAP', '2022-07-26'),
#  ('XNAS.ITCH', 'SAP', '2022-06-27'),
#  ('XNAS.ITCH', 'SAP', '2020-08-12'),
#  ('XNAS.ITCH', 'SAP', '2021-12-13'),
#  ('XNAS.ITCH', 'SAP', '2021-02-12'),
#  ('XNAS.ITCH', 'SAP', '2021-10-20'),
#  ('XNAS.ITCH', 'SAP', '2020-02-27'),
#  ('XNAS.ITCH', 'SAP', '2022-12-16'),
#  ('XNAS.ITCH', 'SAP', '2021-02-09'),
#  ('XNAS.ITCH', 'SAP', '2020-04-08'),
#  ('XNAS.ITCH', 'SAP', '2025-10-23'),
#  ('XNAS.ITCH', 'SAP', '2020-09-21'),
#  ('XNAS.ITCH', 'SAP', '2024-07-29'),
#  ('XNAS.ITCH', 'SAP', '2024-04-12'),
#  ('XNAS.ITCH', 'SAP', '2020-05-13'),
#  ('XNAS.ITCH', 'SAP', '2021-08-23'),
#  ('XNAS.ITCH', 'SAP', '2025-09-15'),
#  ('XNAS.ITCH', 'SAP', '2025-04-11'),
#  ('XNAS.ITCH', 'SAP', '2023-07-25'),
#  ('XNAS.ITCH', 'SAP', '2020-10-01'),
#  ('XNAS.ITCH', 'SAP', '2023-01-26'),
#  ('XNAS.ITCH', 'SAP', '2023-04-14'),
#  ('XNAS.ITCH', 'SAP', '2025-06-30'),
#  ('XNAS.ITCH', 'SAP', '2023-02-13'),
#  ('XNAS.ITCH', 'SAP', '2024-06-13'),
#  ('XNAS.ITCH', 'SAP', '2023-11-03'),
#  ('XNAS.ITCH', 'SAP', '2022-12-30'),
#  ('XNAS.ITCH', 'SAP', '2021-11-29'),
#  ('XNAS.ITCH', 'SAP', '2022-05-27'),
#  ('XNAS.ITCH', 'SAP', '2023-02-22'),
#  ('XNAS.ITCH', 'SAP', '2020-04-06'),
#  ('XNAS.ITCH', 'SAP', '2022-05-06'),
#  ('XNAS.ITCH', 'SAP', '2024-07-08'),
#  ('XNAS.ITCH', 'SAP', '2021-01-12'),
#  ('XNAS.ITCH', 'SAP', '2022-02-02'),
#  ('XNAS.ITCH', 'SAP', '2024-04-18'),
#  ('XNAS.ITCH', 'SAP', '2025-03-07'),
#  ('XNAS.ITCH', 'SAP', '2022-10-19'),
#  ('XNAS.ITCH', 'SAP', '2022-02-04'),
#  ('XNAS.ITCH', 'SAP', '2021-01-27'),
#  ('XNAS.ITCH', 'SAP', '2022-03-07'),
#  ('XNAS.ITCH', 'SAP', '2022-03-16'),
#  ('XNAS.ITCH', 'SAP', '2021-04-26'),
#  ('XNAS.ITCH', 'SAP', '2023-10-25'),
#  ('XNAS.ITCH', 'SAP', '2023-01-25'),
#  ('XNAS.ITCH', 'SAP', '2024-04-30'),
#  ('XNAS.ITCH', 'SAP', '2020-04-24'),
#  ('XNAS.ITCH', 'SAP', '2023-08-08'),
#  ('XNAS.ITCH', 'SAP', '2022-11-18'),
#  ('XNAS.ITCH', 'SAP', '2024-05-30'),
#  ('XNAS.ITCH', 'SAP', '2023-02-28'),
#  ('XNAS.ITCH', 'SAP', '2023-08-01'),
#  ('XNAS.ITCH', 'SAP', '2023-01-31'),
#  ('XNAS.ITCH', 'SAP', '2024-06-25'),
#  ('XNAS.ITCH', 'SAP', '2021-07-02'),
#  ('XNAS.ITCH', 'SAP', '2021-10-08'),
#  ('XNAS.ITCH', 'SAP', '2020-11-04'),
#  ('XNAS.ITCH', 'SAP', '2025-02-24'),
#  ('XNAS.ITCH', 'SAP', '2024-07-24'),
#  ('XNAS.ITCH', 'SAP', '2024-10-10'),
#  ('XNAS.ITCH', 'SAP', '2023-02-03'),
#  ('XNAS.ITCH', 'SAP', '2024-11-13'),
#  ('XNAS.ITCH', 'SAP', '2021-06-01'),
#  ('XNAS.ITCH', 'SAP', '2021-06-02'),
#  ('XNAS.ITCH', 'SAP', '2023-11-10'),
#  ('XNAS.ITCH', 'SAP', '2023-01-27'),
#  ('XNAS.ITCH', 'SAP', '2022-08-29'),
#  ('XNAS.ITCH', 'SAP', '2023-12-08'),
#  ('XNAS.ITCH', 'SAP', '2022-10-12'),
#  ('XNAS.ITCH', 'SAP', '2024-05-10'),
#  ('XNAS.ITCH', 'SAP', '2025-01-10'),
#  ('XNAS.ITCH', 'SAP', '2020-05-11'),
#  ('XNAS.ITCH', 'SAP', '2021-09-07'),
#  ('XNAS.ITCH', 'SAP', '2022-09-22'),
#  ('XNAS.ITCH', 'SAP', '2025-09-17'),
#  ('XNAS.ITCH', 'SAP', '2021-03-10'),
#  ('XNAS.ITCH', 'SAP', '2024-07-12'),
#  ('XNAS.ITCH', 'SAP', '2021-01-26'),
#  ('XNAS.ITCH', 'SAP', '2025-01-30'),
#  ('XNAS.ITCH', 'SAP', '2024-05-02'),
#  ('XNAS.ITCH', 'SAP', '2023-04-06'),
#  ('XNAS.ITCH', 'SAP', '2021-10-04'),
#  ('XNAS.ITCH', 'SAP', '2022-10-26'),
#  ('XNAS.ITCH', 'SAP', '2021-06-23'),
#  ('XNAS.ITCH', 'SAP', '2023-04-24'),
#  ('XNAS.ITCH', 'SAP', '2022-07-20'),
#  ('XNAS.ITCH', 'SAP', '2024-11-15'),
#  ('XNAS.ITCH', 'SAP', '2021-09-09'),
#  ('XNAS.ITCH', 'SAP', '2020-08-06'),
#  ('XNAS.ITCH', 'SAP', '2023-12-01'),
#  ('XNAS.ITCH', 'SAP', '2021-07-26'),
#  ('XNAS.ITCH', 'SAP', '2025-08-28'),
#  ('XNAS.ITCH', 'SAP', '2021-11-23'),
#  ('XNAS.ITCH', 'SAP', '2025-03-14'),
#  ('XNAS.ITCH', 'SAP', '2021-10-25'),
#  ('XNAS.ITCH', 'SAP', '2024-10-11'),
#  ('XNAS.ITCH', 'SAP', '2023-03-08'),
#  ('XNAS.ITCH', 'SAP', '2025-04-30'),
#  ('XNAS.ITCH', 'SAP', '2021-07-07'),
#  ('XNAS.ITCH', 'SAP', '2023-04-11'),
#  ('XNAS.ITCH', 'SAP', '2024-10-15'),
#  ('XNAS.ITCH', 'SAP', '2025-10-30'),
#  ('XNAS.ITCH', 'SAP', '2025-09-26'),
#  ('XNAS.ITCH', 'SAP', '2020-08-25'),
#  ('XNAS.ITCH', 'SAP', '2021-06-10'),
#  ('XNAS.ITCH', 'SAP', '2021-07-21'),
#  ('XNAS.ITCH', 'SAP', '2024-02-05'),
#  ('XNAS.ITCH', 'SAP', '2025-03-28'),
#  ('XNAS.ITCH', 'SAP', '2025-04-17'),
#  ('XNAS.ITCH', 'SAP', '2020-04-20'),
#  ('XNAS.ITCH', 'SAP', '2022-05-23'),
#  ('XNAS.ITCH', 'SAP', '2023-09-13'),
#  ('XNAS.ITCH', 'SAP', '2022-08-10'),
#  ('XNAS.ITCH', 'SAP', '2022-02-28'),
#  ('XNAS.ITCH', 'SAP', '2023-08-11'),
#  ('XNAS.ITCH', 'SAP', '2020-06-18'),
#  ('XNAS.ITCH', 'SAP', '2024-10-31'),
#  ('XNAS.ITCH', 'SAP', '2020-02-26'),
#  ('XNAS.ITCH', 'SAP', '2022-11-21'),
#  ('XNAS.ITCH', 'SAP', '2020-11-10'),
#  ('XNAS.ITCH', 'SAP', '2022-03-30'),
#  ('XNAS.ITCH', 'SAP', '2022-05-19'),
#  ('XNAS.ITCH', 'SAP', '2022-02-11'),
#  ('XNAS.ITCH', 'SAP', '2024-01-26'),
#  ('XNAS.ITCH', 'SAP', '2020-04-16'),
#  ('XNAS.ITCH', 'SAP', '2024-06-07'),
#  ('XNAS.ITCH', 'SAP', '2020-02-05'),
#  ('XNAS.ITCH', 'SAP', '2022-09-30'),
#  ('XNAS.ITCH', 'SAP', '2022-02-01'),
#  ('XNAS.ITCH', 'SAP', '2024-03-12'),
#  ('XNAS.ITCH', 'SAP', '2023-09-22'),
#  ('XNAS.ITCH', 'SAP', '2022-04-22'),
#  ('XNAS.ITCH', 'SAP', '2020-10-23'),
#  ('XNAS.ITCH', 'SAP', '2021-08-16'),
#  ('XNAS.ITCH', 'SAP', '2021-10-13'),
#  ('XNAS.ITCH', 'SAP', '2023-04-26'),
#  ('XNAS.ITCH', 'SAP', '2020-03-20'),
#  ('XNAS.ITCH', 'SAP', '2025-08-20'),
#  ('XNAS.ITCH', 'SAP', '2025-06-27'),
#  ('XNAS.ITCH', 'SAP', '2022-07-25'),
#  ('XNAS.ITCH', 'SAP', '2023-03-29'),
#  ('XNAS.ITCH', 'SAP', '2023-10-19'),
#  ('XNAS.ITCH', 'SAP', '2022-02-24'),
#  ('XNAS.ITCH', 'SAP', '2024-06-27'),
#  ('XNAS.ITCH', 'SAP', '2024-08-12'),
#  ('XNAS.ITCH', 'SAP', '2023-02-07'),
#  ('XNAS.ITCH', 'SAP', '2020-08-19'),
#  ('XNAS.ITCH', 'SAP', '2023-02-16'),
#  ('XNAS.ITCH', 'SAP', '2021-01-15'),
#  ('XNAS.ITCH', 'SAP', '2022-02-16'),
#  ('XNAS.ITCH', 'SAP', '2022-02-25'),
#  ('XNAS.ITCH', 'SAP', '2020-11-09'),
#  ('XNAS.ITCH', 'SAP', '2024-01-29'),
#  ('XNAS.ITCH', 'SAP', '2024-09-05'),
#  ('XNAS.ITCH', 'SAP', '2023-09-21'),
#  ('XNAS.ITCH', 'SAP', '2025-04-22'),
#  ('XNAS.ITCH', 'SAP', '2023-04-12'),
#  ('XNAS.ITCH', 'SAP', '2025-03-21'),
#  ('XNAS.ITCH', 'SAP', '2023-10-05'),
#  ('XNAS.ITCH', 'SAP', '2023-07-26'),
#  ('XNAS.ITCH', 'SAP', '2020-05-06'),
#  ('XNAS.ITCH', 'SAP', '2021-07-15'),
#  ('XNAS.ITCH', 'SAP', '2022-07-12'),
#  ('XNAS.ITCH', 'SAP', '2021-11-01'),
#  ('XNAS.ITCH', 'SAP', '2024-12-05'),
#  ('XNAS.ITCH', 'SAP', '2022-05-13'),
#  ('XNAS.ITCH', 'SAP', '2023-03-17'),
#  ('XNAS.ITCH', 'SAP', '2021-08-19'),
#  ('XNAS.ITCH', 'SAP', '2024-10-03'),
#  ('XNAS.ITCH', 'SAP', '2024-01-16'),
#  ('XNAS.ITCH', 'SAP', '2020-09-03'),
#  ('XNAS.ITCH', 'SAP', '2024-03-26'),
#  ('XNAS.ITCH', 'SAP', '2021-03-08'),
#  ('XNAS.ITCH', 'SAP', '2024-04-08'),
#  ('XNAS.ITCH', 'SAP', '2021-03-17'),
#  ('XNAS.ITCH', 'SAP', '2023-10-02'),
#  ('XNAS.ITCH', 'SAP', '2021-09-16'),
#  ('XNAS.ITCH', 'SAP', '2023-12-11'),
#  ('XNAS.ITCH', 'SAP', '2025-07-10'),
#  ('XNAS.ITCH', 'SAP', '2023-07-17'),
#  ('XNAS.ITCH', 'SAP', '2020-02-20'),
#  ('XNAS.ITCH', 'SAP', '2021-10-05'),
#  ('XNAS.ITCH', 'SAP', '2021-07-12'),
#  ('XNAS.ITCH', 'SAP', '2023-04-04'),
#  ('XNAS.ITCH', 'SAP', '2020-08-31'),
#  ('XNAS.ITCH', 'SAP', '2020-09-28'),
#  ('XNAS.ITCH', 'SAP', '2024-05-17'),
#  ('XNAS.ITCH', 'SAP', '2025-02-26'),
#  ('XNAS.ITCH', 'SAP', '2023-03-13'),
#  ('XNAS.ITCH', 'SAP', '2024-11-27'),
#  ('XNAS.ITCH', 'SAP', '2023-10-27'),
#  ('XNAS.ITCH', 'SAP', '2025-04-21'),
#  ('XNAS.ITCH', 'SAP', '2021-08-09'),
#  ('XNAS.ITCH', 'SAP', '2022-08-08'),
#  ('XNAS.ITCH', 'SAP', '2021-07-19'),
#  ('XNAS.ITCH', 'SAP', '2025-03-03'),
#  ('XNAS.ITCH', 'SAP', '2025-08-22'),
#  ('XNAS.ITCH', 'SAP', '2025-05-07'),
#  ('XNAS.ITCH', 'SAP', '2021-11-10'),
#  ('XNAS.ITCH', 'SAP', '2024-05-06'),
#  ('XNAS.ITCH', 'SAP', '2024-11-01'),
#  ('XNAS.ITCH', 'SAP', '2025-01-28'),
#  ('XNAS.ITCH', 'SAP', '2025-07-22'),
#  ('XNAS.ITCH', 'SAP', '2024-04-16'),
#  ('XNAS.ITCH', 'SAP', '2023-07-03'),
#  ('XNAS.ITCH', 'SAP', '2022-09-28'),
#  ('XNAS.ITCH', 'SAP', '2020-07-01'),
#  ('XNAS.ITCH', 'SAP', '2024-07-17'),
#  ('XNAS.ITCH', 'SAP', '2024-06-10'),
#  ('XNAS.ITCH', 'SAP', '2020-03-24'),
#  ('XNAS.ITCH', 'SAP', '2025-09-08'),
#  ('XNAS.ITCH', 'SAP', '2021-11-15'),
#  ('XNAS.ITCH', 'SAP', '2025-02-20'),
#  ('XNAS.ITCH', 'SAP', '2020-08-20'),
#  ('XNAS.ITCH', 'SAP', '2021-01-08'),
#  ('XNAS.ITCH', 'SAP', '2025-08-08'),
#  ('XNAS.ITCH', 'SAP', '2022-10-06'),
#  ('XNAS.ITCH', 'SAP', '2024-08-23'),
#  ('XNAS.ITCH', 'SAP', '2023-09-08'),
#  ('XNAS.ITCH', 'SAP', '2023-10-18'),
#  ('XNAS.ITCH', 'SAP', '2021-02-25'),
#  ('XNAS.ITCH', 'SAP', '2023-11-22'),
#  ('XNAS.ITCH', 'SAP', '2021-01-04'),
#  ('XNAS.ITCH', 'SAP', '2023-05-24'),
#  ('XNAS.ITCH', 'SAP', '2023-07-28'),
#  ('XNAS.ITCH', 'SAP', '2022-10-24'),
#  ('XNAS.ITCH', 'SAP', '2025-08-26'),
#  ('XNAS.ITCH', 'SAP', '2021-10-29'),
#  ('XNAS.ITCH', 'SAP', '2021-06-15'),
#  ('XNAS.ITCH', 'SAP', '2020-11-27'),
#  ('XNAS.ITCH', 'SAP', '2023-09-29'),
#  ('XNAS.ITCH', 'SAP', '2022-03-09'),
#  ('XNAS.ITCH', 'SAP', '2024-09-17'),
#  ('XNAS.ITCH', 'SAP', '2023-05-17'),
#  ('XNAS.ITCH', 'SAP', '2021-04-22'),
#  ('XNAS.ITCH', 'SAP', '2022-01-07'),
#  ('XNAS.ITCH', 'SAP', '2022-01-27'),
#  ('XNAS.ITCH', 'SAP', '2023-03-20'),
#  ('XNAS.ITCH', 'SAP', '2024-10-22'),
#  ('XNAS.ITCH', 'SAP', '2025-02-04'),
#  ('XNAS.ITCH', 'SAP', '2020-07-23'),
#  ('XNAS.ITCH', 'SAP', '2020-04-23'),
#  ('XNAS.ITCH', 'SAP', '2023-01-09'),
#  ('XNAS.ITCH', 'SAP', '2021-07-22'),
#  ('XNAS.ITCH', 'SAP', '2023-01-10'),
#  ('XNAS.ITCH', 'SAP', '2022-07-21'),
#  ('XNAS.ITCH', 'SAP', '2025-02-18'),
#  ('XNAS.ITCH', 'SAP', '2020-02-06'),
#  ('XNAS.ITCH', 'SAP', '2024-07-11'),
#  ('XNAS.ITCH', 'SAP', '2022-07-18'),
#  ('XNAS.ITCH', 'SAP', '2023-07-31'),
#  ...]

# %%
pattern_str
# Out:
# 'exchange=(?P<exchange>[^/]+)/ticker=(?P<ticker>[^/]+)/date=(?P<date>[^/]+)/'

# %%
from glob import glob
s_all = ','.join(glob(os.path.join('../data/raw/adrs/bbo-1m/by_exchange/','*','*','*')))

# %%
import re
from glob import glob

partition_path = '../data/raw/adrs/bbo-1m/by_exchange/'
s = ','.join(glob(os.path.join(partition_path,'*=*','*=*','date=*')))
pattern = re.compile(r"ticker=(?P<ticker>[^/]+)/date=(?P<date>\d{4}-\d{2}-\d{2})")
dates = pattern.findall(s)
# def get_partition_dates(partition_path):
#     s = ','.join(glob(os.path.join(partition_path,'*=*','date=*')))
#     pattern = re.compile(r"date=(?P<date>\d{4}-\d{2}-\d{2})")
#     dates = pattern.findall(s)
    
#     return sorted(list(set(dates)))

# %%
glob(os.path.join(partition_path,'*','*','*','*.parquet'))
# Out:
# ['../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-01-11/da95c6f5e9184a22806b9370501695c9-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-02-28/92ae0e78677740f7a13d5ff1b7eef3d0-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-08-29/e131693509ea409dbccf448454b144a4-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-08-01/9c536d0a889e4987bad7c0929cad5734-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-01-24/37c1ddf4963f4e30acd4b8429a5e6fe3-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-08-07/05df8db79d6348e18b15cea545a0737f-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-04-18/0116623f8c15438788fdcb04e4728511-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-01-19/acae8849c65d4b4da8fa40c38aba6956-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-11-24/db6e3be23aed4c91861c7b5997c21672-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-09-02/c7b584e0e3144d13a46a15a1210c72b0-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-02-03/60082317d0444162b58f0ab6696875cc-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-09-02/b7d033ee629a4ef2aa40f1c2b70be550-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-10-02/537a50c55ba247e2b03e9cca281f2fcd-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-03-06/3b3035da6b3442afa67f0f41931bfc31-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-08-27/3c8c8f8fbec440a98ffb82009bf7d977-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-02-02/823aaf1e147c464bac03715a66c2d58f-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-07-17/71c557dea220421387b42c456a017bf9-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-10-17/f68ef0781ee14733b255a56c02979e24-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-08-02/3c8c8f8fbec440a98ffb82009bf7d977-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-07-02/d35a1f37a3db4b15920aba26b6e98c85-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-04-03/78b121c52618463fb4f8bef0e5a2108e-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-12-21/cfa3e75b2b924fc7a1a23b22c1377f0c-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-08-13/54c773aa1d3d4aa8ad45b207ff9bed60-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-01-22/cf26908c73d84213b0884f7eb684ace6-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-02-15/3bab5f18f4f0404096dcf8bbb02ceef5-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-05-07/d7ba36ed08db43a788381ed2bc711507-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-05-14/62acda0e4c0c4990bcc6db3aa5479f9e-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-08-19/9c536d0a889e4987bad7c0929cad5734-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-02-07/92ae0e78677740f7a13d5ff1b7eef3d0-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-02-18/b6ebae68c46047059d634dd31c9dabec-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-01-22/5e6303bc445d47ffbbab670f071b303d-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-04-05/0116623f8c15438788fdcb04e4728511-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-03-18/747a8b8ef7584adfba65805d04aecee6-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-09-10/fa775408436246199e126f9934ca6f6a-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-08-06/e131693509ea409dbccf448454b144a4-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-02-12/3bab5f18f4f0404096dcf8bbb02ceef5-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-11-18/0eef3bbbf1744162940c22122a083e60-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-08-16/1ae02ae5e58b4d408abb14b019f22792-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-11-05/db6e3be23aed4c91861c7b5997c21672-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-10-14/f68ef0781ee14733b255a56c02979e24-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-09-13/c7b584e0e3144d13a46a15a1210c72b0-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-06-23/f38874d4005342dda94fb19a99f9fc1d-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-01-09/acae8849c65d4b4da8fa40c38aba6956-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-12-02/5f1052b6b5ea4fcdadf4b4836e0ebcbd-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-09-02/fa775408436246199e126f9934ca6f6a-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-01-04/acae8849c65d4b4da8fa40c38aba6956-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-01-23/cf26908c73d84213b0884f7eb684ace6-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-02-24/823aaf1e147c464bac03715a66c2d58f-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-01-16/5e6303bc445d47ffbbab670f071b303d-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-12-06/320df8eb1381431581b8a70263d67baa-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-01-24/5e6303bc445d47ffbbab670f071b303d-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-03-29/d57c3bec31d24720bd20ad047be14569-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-12-07/5f1052b6b5ea4fcdadf4b4836e0ebcbd-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-10-23/f68ef0781ee14733b255a56c02979e24-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-08-25/9c536d0a889e4987bad7c0929cad5734-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-11-01/5272b4cb6b90473d8caf862ec73d816a-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-07-29/cb51cdcfb88f456bb3c0109d09643ba2-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-06-01/a68e4d2d5a274797ad51c8157d19658c-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-12-27/037cd90e226542b99dc94dfad0967412-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-09-15/c7b584e0e3144d13a46a15a1210c72b0-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-01-03/5e6303bc445d47ffbbab670f071b303d-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-01-26/da95c6f5e9184a22806b9370501695c9-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-08-28/1ae02ae5e58b4d408abb14b019f22792-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-01-24/da95c6f5e9184a22806b9370501695c9-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-01-22/429ccdf409144a2e920d7e52442dff02-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-01-07/429ccdf409144a2e920d7e52442dff02-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-02-03/b6ebae68c46047059d634dd31c9dabec-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-05-15/d7ba36ed08db43a788381ed2bc711507-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-06-06/8c0968be56334fffbcf8436f92767309-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-11-08/db6e3be23aed4c91861c7b5997c21672-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-10-25/b7d8ae1e636942b8abaf72deb3f49df1-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-06-30/a68e4d2d5a274797ad51c8157d19658c-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-05-07/8d28714dc4e2478db0294426a9e4580b-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-12-15/037cd90e226542b99dc94dfad0967412-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-07-15/a8805b56087a48c7a9b7d1f31888ca1e-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-08-13/05df8db79d6348e18b15cea545a0737f-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-05-11/722de05e8fd943d2a935e79f67d90ba7-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-06-24/23d85a79854744fe96c8cacc5662af57-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-06-26/a68e4d2d5a274797ad51c8157d19658c-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-04-02/93763a64fab54d718a62adb2ae59019a-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-10-11/56427680a37c44c289859b2488e626a3-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-01-25/acae8849c65d4b4da8fa40c38aba6956-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-06-14/23d85a79854744fe96c8cacc5662af57-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-03-31/cb5dea63b8f74a1e8e828ee3b137e2fc-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-10-05/b7d8ae1e636942b8abaf72deb3f49df1-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-08-14/05df8db79d6348e18b15cea545a0737f-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-10-07/537a50c55ba247e2b03e9cca281f2fcd-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-06-30/e970ad8c85a845f1ba2ac187411817a0-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-05-08/62acda0e4c0c4990bcc6db3aa5479f9e-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-03-26/3b3035da6b3442afa67f0f41931bfc31-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-01-17/cf26908c73d84213b0884f7eb684ace6-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-12-24/320df8eb1381431581b8a70263d67baa-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-02-21/823aaf1e147c464bac03715a66c2d58f-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-06-21/23d85a79854744fe96c8cacc5662af57-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-08-05/e131693509ea409dbccf448454b144a4-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-11-30/87f5ac967e474052b6c9779f804ee860-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-08-05/3c8c8f8fbec440a98ffb82009bf7d977-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-07-14/a8805b56087a48c7a9b7d1f31888ca1e-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-06-05/23d85a79854744fe96c8cacc5662af57-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-07-15/71c557dea220421387b42c456a017bf9-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-11-29/5d1c0f0b2bec4370b047c125013e1d91-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-02-10/8054848d81a646099f2f757044377a66-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-01-30/acae8849c65d4b4da8fa40c38aba6956-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-04-15/8162144895c44ff1a8ade25633efe296-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-01-06/429ccdf409144a2e920d7e52442dff02-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-05-29/62acda0e4c0c4990bcc6db3aa5479f9e-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-05-26/678dcc5da4074d0aac053166f365a5e0-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-07-03/71c557dea220421387b42c456a017bf9-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-06-18/23d85a79854744fe96c8cacc5662af57-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-07-29/a8805b56087a48c7a9b7d1f31888ca1e-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-03-14/8739a60e4ba141fa9fcefbb23392737a-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-11-25/0eef3bbbf1744162940c22122a083e60-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-04-03/3d24d1e2dc914186991b4e1663c36890-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-09-05/67d5265ff6af441b91f2bed3e3bcc09c-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-04-23/93763a64fab54d718a62adb2ae59019a-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-06-06/23d85a79854744fe96c8cacc5662af57-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-09-30/b7d033ee629a4ef2aa40f1c2b70be550-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-12-16/efd852d9929b423593d082df216131e7-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-07-16/71c557dea220421387b42c456a017bf9-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-04-27/3d24d1e2dc914186991b4e1663c36890-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-04-21/0116623f8c15438788fdcb04e4728511-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-05-01/d7ba36ed08db43a788381ed2bc711507-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-03-08/8739a60e4ba141fa9fcefbb23392737a-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-06-22/a68e4d2d5a274797ad51c8157d19658c-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-01-11/37c1ddf4963f4e30acd4b8429a5e6fe3-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-04-29/57d1a2ed2feb40ffbfdc1cb7bcfe707f-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-09-09/fa775408436246199e126f9934ca6f6a-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-12-30/320df8eb1381431581b8a70263d67baa-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-10-22/20254eb32c974446b22d8e0e25f89709-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-08-19/e131693509ea409dbccf448454b144a4-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-08-12/9c536d0a889e4987bad7c0929cad5734-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-12-30/efd852d9929b423593d082df216131e7-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-06-17/a68e4d2d5a274797ad51c8157d19658c-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-05-13/8d28714dc4e2478db0294426a9e4580b-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-08-21/1ae02ae5e58b4d408abb14b019f22792-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-04-20/57d1a2ed2feb40ffbfdc1cb7bcfe707f-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-01-27/cf26908c73d84213b0884f7eb684ace6-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-12-05/5f1052b6b5ea4fcdadf4b4836e0ebcbd-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-09-04/61b05420237f45e6b382db523812deea-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-05-09/678dcc5da4074d0aac053166f365a5e0-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-06-03/7bf58077eed7456687c81d6e9f2c7f8e-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-07-18/5e07cd2d2ec64756a2d7117c35b120ad-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-04-07/0116623f8c15438788fdcb04e4728511-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-09-14/fa775408436246199e126f9934ca6f6a-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-06-13/f38874d4005342dda94fb19a99f9fc1d-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-05-12/62acda0e4c0c4990bcc6db3aa5479f9e-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-09-13/61b05420237f45e6b382db523812deea-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-09-20/d4beb5727f7c4a1d8cffa731c07acb05-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-05-03/722de05e8fd943d2a935e79f67d90ba7-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-09-15/d4beb5727f7c4a1d8cffa731c07acb05-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-04-27/57d1a2ed2feb40ffbfdc1cb7bcfe707f-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-05-22/678dcc5da4074d0aac053166f365a5e0-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-01-06/37c1ddf4963f4e30acd4b8429a5e6fe3-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-09-29/67d5265ff6af441b91f2bed3e3bcc09c-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-06-02/7bf58077eed7456687c81d6e9f2c7f8e-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-06-04/a68e4d2d5a274797ad51c8157d19658c-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-05-26/6de306ca406c43b884b58e5f7905fd87-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-12-16/320df8eb1381431581b8a70263d67baa-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-03-22/8739a60e4ba141fa9fcefbb23392737a-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-05-02/678dcc5da4074d0aac053166f365a5e0-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-09-12/c7b584e0e3144d13a46a15a1210c72b0-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-05-05/6de306ca406c43b884b58e5f7905fd87-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-06-30/7bf58077eed7456687c81d6e9f2c7f8e-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-09-23/b7d033ee629a4ef2aa40f1c2b70be550-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-11-30/db6e3be23aed4c91861c7b5997c21672-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-03-11/3b3035da6b3442afa67f0f41931bfc31-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-06-16/e970ad8c85a845f1ba2ac187411817a0-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-12-19/037cd90e226542b99dc94dfad0967412-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-01-21/cf26908c73d84213b0884f7eb684ace6-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-01-14/429ccdf409144a2e920d7e52442dff02-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-01-16/cf26908c73d84213b0884f7eb684ace6-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-06-26/f38874d4005342dda94fb19a99f9fc1d-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-05-17/722de05e8fd943d2a935e79f67d90ba7-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-01-20/37c1ddf4963f4e30acd4b8429a5e6fe3-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-04-13/8162144895c44ff1a8ade25633efe296-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-11-22/0eef3bbbf1744162940c22122a083e60-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-04-12/0116623f8c15438788fdcb04e4728511-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-11-16/5d1c0f0b2bec4370b047c125013e1d91-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-11-17/5d1c0f0b2bec4370b047c125013e1d91-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-09-10/67d5265ff6af441b91f2bed3e3bcc09c-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-11-12/0eef3bbbf1744162940c22122a083e60-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-04-14/0116623f8c15438788fdcb04e4728511-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-06-18/8c0968be56334fffbcf8436f92767309-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-06-01/7bf58077eed7456687c81d6e9f2c7f8e-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-02-06/823aaf1e147c464bac03715a66c2d58f-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-03-05/8739a60e4ba141fa9fcefbb23392737a-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-08-04/3c8c8f8fbec440a98ffb82009bf7d977-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-01-13/5e6303bc445d47ffbbab670f071b303d-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-10-10/b7d8ae1e636942b8abaf72deb3f49df1-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-08-10/3c8c8f8fbec440a98ffb82009bf7d977-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-04-10/3d24d1e2dc914186991b4e1663c36890-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-06-19/a68e4d2d5a274797ad51c8157d19658c-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-06-22/f38874d4005342dda94fb19a99f9fc1d-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-07-17/a8805b56087a48c7a9b7d1f31888ca1e-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-08-04/9c536d0a889e4987bad7c0929cad5734-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-04-27/0116623f8c15438788fdcb04e4728511-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-02-08/b6ebae68c46047059d634dd31c9dabec-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-06-17/7bf58077eed7456687c81d6e9f2c7f8e-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-02-14/823aaf1e147c464bac03715a66c2d58f-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-03-04/3b3035da6b3442afa67f0f41931bfc31-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-09-18/67d5265ff6af441b91f2bed3e3bcc09c-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-12-14/5f1052b6b5ea4fcdadf4b4836e0ebcbd-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-03-27/8739a60e4ba141fa9fcefbb23392737a-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-12-03/efd852d9929b423593d082df216131e7-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-11-21/0eef3bbbf1744162940c22122a083e60-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-10-03/8b1a81da5a5d443fb44e07c9e9c22d0c-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-03-15/cb5dea63b8f74a1e8e828ee3b137e2fc-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-08-18/1ae02ae5e58b4d408abb14b019f22792-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-07-07/71c557dea220421387b42c456a017bf9-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-01-24/cf26908c73d84213b0884f7eb684ace6-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-02-27/3bab5f18f4f0404096dcf8bbb02ceef5-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-07-08/addaf4b4950e42ecaea96872da315c63-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-04-07/8162144895c44ff1a8ade25633efe296-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-12-09/cfa3e75b2b924fc7a1a23b22c1377f0c-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-09-16/67d5265ff6af441b91f2bed3e3bcc09c-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-10-20/8b1a81da5a5d443fb44e07c9e9c22d0c-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-05-16/62acda0e4c0c4990bcc6db3aa5479f9e-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-03-02/cb5dea63b8f74a1e8e828ee3b137e2fc-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-10-01/537a50c55ba247e2b03e9cca281f2fcd-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-10-06/8b1a81da5a5d443fb44e07c9e9c22d0c-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-03-30/1203bb972655474f8835ee91e242e409-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-01-08/acae8849c65d4b4da8fa40c38aba6956-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-08-07/1ae02ae5e58b4d408abb14b019f22792-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-06-11/8c0968be56334fffbcf8436f92767309-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-04-01/78b121c52618463fb4f8bef0e5a2108e-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-05-30/678dcc5da4074d0aac053166f365a5e0-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-12-10/cfa3e75b2b924fc7a1a23b22c1377f0c-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-08-26/3c8c8f8fbec440a98ffb82009bf7d977-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-01-07/cf26908c73d84213b0884f7eb684ace6-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-08-09/9c536d0a889e4987bad7c0929cad5734-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-03-02/1203bb972655474f8835ee91e242e409-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-01-30/37c1ddf4963f4e30acd4b8429a5e6fe3-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-01-05/429ccdf409144a2e920d7e52442dff02-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-04-04/93763a64fab54d718a62adb2ae59019a-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-03-15/1203bb972655474f8835ee91e242e409-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-04-23/57d1a2ed2feb40ffbfdc1cb7bcfe707f-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-11-28/5d1c0f0b2bec4370b047c125013e1d91-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-10-03/b7d8ae1e636942b8abaf72deb3f49df1-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-08-18/9c536d0a889e4987bad7c0929cad5734-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-06-12/23d85a79854744fe96c8cacc5662af57-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-05-01/62acda0e4c0c4990bcc6db3aa5479f9e-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-09-08/fa775408436246199e126f9934ca6f6a-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-09-03/67d5265ff6af441b91f2bed3e3bcc09c-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-04-14/8162144895c44ff1a8ade25633efe296-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-05-06/62acda0e4c0c4990bcc6db3aa5479f9e-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-11-16/87f5ac967e474052b6c9779f804ee860-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-05-23/62acda0e4c0c4990bcc6db3aa5479f9e-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-05-23/8d28714dc4e2478db0294426a9e4580b-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-09-25/61b05420237f45e6b382db523812deea-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-05-21/d7ba36ed08db43a788381ed2bc711507-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-09-04/fa775408436246199e126f9934ca6f6a-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-05-28/722de05e8fd943d2a935e79f67d90ba7-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-08-01/e131693509ea409dbccf448454b144a4-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-01-05/37c1ddf4963f4e30acd4b8429a5e6fe3-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-03-09/1203bb972655474f8835ee91e242e409-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-07-20/addaf4b4950e42ecaea96872da315c63-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-05-01/678dcc5da4074d0aac053166f365a5e0-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-04-15/93763a64fab54d718a62adb2ae59019a-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-01-05/da95c6f5e9184a22806b9370501695c9-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-03-21/1203bb972655474f8835ee91e242e409-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-02-23/823aaf1e147c464bac03715a66c2d58f-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-10-04/b7d8ae1e636942b8abaf72deb3f49df1-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-07-10/a8805b56087a48c7a9b7d1f31888ca1e-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-05-18/6de306ca406c43b884b58e5f7905fd87-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-01-13/cf26908c73d84213b0884f7eb684ace6-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-03-01/d57c3bec31d24720bd20ad047be14569-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-08-03/9c536d0a889e4987bad7c0929cad5734-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-07-25/71c557dea220421387b42c456a017bf9-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-07-18/d35a1f37a3db4b15920aba26b6e98c85-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-11-04/5d1c0f0b2bec4370b047c125013e1d91-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-12-28/cfa3e75b2b924fc7a1a23b22c1377f0c-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-05-12/6de306ca406c43b884b58e5f7905fd87-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-12-29/037cd90e226542b99dc94dfad0967412-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-09-18/fa775408436246199e126f9934ca6f6a-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-07-30/a8805b56087a48c7a9b7d1f31888ca1e-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-06-07/e970ad8c85a845f1ba2ac187411817a0-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-04-08/0116623f8c15438788fdcb04e4728511-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-10-24/537a50c55ba247e2b03e9cca281f2fcd-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-10-27/b7d8ae1e636942b8abaf72deb3f49df1-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-06-20/8c0968be56334fffbcf8436f92767309-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-07-22/a8805b56087a48c7a9b7d1f31888ca1e-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-08-09/1ae02ae5e58b4d408abb14b019f22792-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-07-16/d35a1f37a3db4b15920aba26b6e98c85-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-08-04/05df8db79d6348e18b15cea545a0737f-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-06-08/a68e4d2d5a274797ad51c8157d19658c-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-12-08/cfa3e75b2b924fc7a1a23b22c1377f0c-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-12-20/efd852d9929b423593d082df216131e7-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-04-27/8162144895c44ff1a8ade25633efe296-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-06-11/23d85a79854744fe96c8cacc5662af57-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-12-27/320df8eb1381431581b8a70263d67baa-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-01-17/5e6303bc445d47ffbbab670f071b303d-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-02-28/8054848d81a646099f2f757044377a66-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-01-20/429ccdf409144a2e920d7e52442dff02-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-08-07/e131693509ea409dbccf448454b144a4-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-10-12/8b1a81da5a5d443fb44e07c9e9c22d0c-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-10-27/537a50c55ba247e2b03e9cca281f2fcd-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-12-03/320df8eb1381431581b8a70263d67baa-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-01-31/cf26908c73d84213b0884f7eb684ace6-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-08-15/05df8db79d6348e18b15cea545a0737f-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-01-15/cf26908c73d84213b0884f7eb684ace6-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-04-17/78b121c52618463fb4f8bef0e5a2108e-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-04-28/0116623f8c15438788fdcb04e4728511-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-12-31/cfa3e75b2b924fc7a1a23b22c1377f0c-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-07-25/d35a1f37a3db4b15920aba26b6e98c85-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-03-29/cb5dea63b8f74a1e8e828ee3b137e2fc-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-04-29/78b121c52618463fb4f8bef0e5a2108e-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-05-27/d7ba36ed08db43a788381ed2bc711507-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-07-18/71c557dea220421387b42c456a017bf9-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-12-20/037cd90e226542b99dc94dfad0967412-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-07-22/cb51cdcfb88f456bb3c0109d09643ba2-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-04-02/78b121c52618463fb4f8bef0e5a2108e-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-09-10/61b05420237f45e6b382db523812deea-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-12-06/037cd90e226542b99dc94dfad0967412-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-07-29/71c557dea220421387b42c456a017bf9-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-04-23/78b121c52618463fb4f8bef0e5a2108e-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-11-07/5272b4cb6b90473d8caf862ec73d816a-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-05-21/62acda0e4c0c4990bcc6db3aa5479f9e-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-05-01/8d28714dc4e2478db0294426a9e4580b-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-09-24/61b05420237f45e6b382db523812deea-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-08-26/e131693509ea409dbccf448454b144a4-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-05-02/6de306ca406c43b884b58e5f7905fd87-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-04-13/3d24d1e2dc914186991b4e1663c36890-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-04-09/78b121c52618463fb4f8bef0e5a2108e-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-11-16/db6e3be23aed4c91861c7b5997c21672-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-06-26/23d85a79854744fe96c8cacc5662af57-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-08-06/3c8c8f8fbec440a98ffb82009bf7d977-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-05-21/722de05e8fd943d2a935e79f67d90ba7-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-07-21/71c557dea220421387b42c456a017bf9-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-06-28/23d85a79854744fe96c8cacc5662af57-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-04-28/8162144895c44ff1a8ade25633efe296-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-05-28/8d28714dc4e2478db0294426a9e4580b-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-04-24/78b121c52618463fb4f8bef0e5a2108e-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-12-22/efd852d9929b423593d082df216131e7-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-12-22/037cd90e226542b99dc94dfad0967412-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-06-29/7bf58077eed7456687c81d6e9f2c7f8e-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-02-10/823aaf1e147c464bac03715a66c2d58f-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-12-10/efd852d9929b423593d082df216131e7-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-09-27/61b05420237f45e6b382db523812deea-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-08-03/3c8c8f8fbec440a98ffb82009bf7d977-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-01-18/da95c6f5e9184a22806b9370501695c9-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-08-16/9c536d0a889e4987bad7c0929cad5734-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-12-11/320df8eb1381431581b8a70263d67baa-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-12-13/037cd90e226542b99dc94dfad0967412-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-11-08/5d1c0f0b2bec4370b047c125013e1d91-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-10-09/20254eb32c974446b22d8e0e25f89709-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-02-19/60082317d0444162b58f0ab6696875cc-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-07-06/cb51cdcfb88f456bb3c0109d09643ba2-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-06-21/7bf58077eed7456687c81d6e9f2c7f8e-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-05-20/8d28714dc4e2478db0294426a9e4580b-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-02-19/92ae0e78677740f7a13d5ff1b7eef3d0-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-04-15/57d1a2ed2feb40ffbfdc1cb7bcfe707f-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-03-22/cb5dea63b8f74a1e8e828ee3b137e2fc-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-09-16/c7b584e0e3144d13a46a15a1210c72b0-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-05-13/722de05e8fd943d2a935e79f67d90ba7-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-02-07/3bab5f18f4f0404096dcf8bbb02ceef5-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-03-28/8739a60e4ba141fa9fcefbb23392737a-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-09-17/b7d033ee629a4ef2aa40f1c2b70be550-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-12-15/cfa3e75b2b924fc7a1a23b22c1377f0c-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-03-03/d57c3bec31d24720bd20ad047be14569-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-08-15/e131693509ea409dbccf448454b144a4-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-02-24/60082317d0444162b58f0ab6696875cc-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-06-13/7bf58077eed7456687c81d6e9f2c7f8e-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-09-23/c7b584e0e3144d13a46a15a1210c72b0-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-02-22/60082317d0444162b58f0ab6696875cc-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-09-11/61b05420237f45e6b382db523812deea-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-03-23/d57c3bec31d24720bd20ad047be14569-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-10-12/56427680a37c44c289859b2488e626a3-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-05-23/678dcc5da4074d0aac053166f365a5e0-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-12-02/cfa3e75b2b924fc7a1a23b22c1377f0c-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-03-09/d57c3bec31d24720bd20ad047be14569-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-10-26/20254eb32c974446b22d8e0e25f89709-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-08-30/e131693509ea409dbccf448454b144a4-0.parquet',
# ...
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-02-01/b6ebae68c46047059d634dd31c9dabec-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-03-12/8739a60e4ba141fa9fcefbb23392737a-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-09-22/d4beb5727f7c4a1d8cffa731c07acb05-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-04-22/0116623f8c15438788fdcb04e4728511-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-10-23/20254eb32c974446b22d8e0e25f89709-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-08-16/3c8c8f8fbec440a98ffb82009bf7d977-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-10-13/56427680a37c44c289859b2488e626a3-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-04-26/3d24d1e2dc914186991b4e1663c36890-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-03-20/747a8b8ef7584adfba65805d04aecee6-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-08-20/05df8db79d6348e18b15cea545a0737f-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-06-27/8c0968be56334fffbcf8436f92767309-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-07-25/cb51cdcfb88f456bb3c0109d09643ba2-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-03-29/1203bb972655474f8835ee91e242e409-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-10-19/8b1a81da5a5d443fb44e07c9e9c22d0c-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-02-24/b6ebae68c46047059d634dd31c9dabec-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-06-27/23d85a79854744fe96c8cacc5662af57-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-08-12/e131693509ea409dbccf448454b144a4-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-02-07/823aaf1e147c464bac03715a66c2d58f-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-08-19/54c773aa1d3d4aa8ad45b207ff9bed60-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-02-16/823aaf1e147c464bac03715a66c2d58f-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-01-15/429ccdf409144a2e920d7e52442dff02-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-02-16/b6ebae68c46047059d634dd31c9dabec-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-02-25/b6ebae68c46047059d634dd31c9dabec-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-11-09/87f5ac967e474052b6c9779f804ee860-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-01-29/acae8849c65d4b4da8fa40c38aba6956-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-09-05/61b05420237f45e6b382db523812deea-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-09-21/d4beb5727f7c4a1d8cffa731c07acb05-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-04-22/93763a64fab54d718a62adb2ae59019a-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-04-12/3d24d1e2dc914186991b4e1663c36890-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-03-21/3b3035da6b3442afa67f0f41931bfc31-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-10-05/8b1a81da5a5d443fb44e07c9e9c22d0c-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-07-26/5e07cd2d2ec64756a2d7117c35b120ad-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-05-06/d7ba36ed08db43a788381ed2bc711507-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-07-15/addaf4b4950e42ecaea96872da315c63-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-07-12/cb51cdcfb88f456bb3c0109d09643ba2-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-11-01/db6e3be23aed4c91861c7b5997c21672-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-12-05/320df8eb1381431581b8a70263d67baa-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-05-13/6de306ca406c43b884b58e5f7905fd87-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-03-17/1203bb972655474f8835ee91e242e409-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-08-19/3c8c8f8fbec440a98ffb82009bf7d977-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-10-03/f68ef0781ee14733b255a56c02979e24-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-01-16/acae8849c65d4b4da8fa40c38aba6956-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-09-03/fa775408436246199e126f9934ca6f6a-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-03-26/8739a60e4ba141fa9fcefbb23392737a-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-03-08/d57c3bec31d24720bd20ad047be14569-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-04-08/78b121c52618463fb4f8bef0e5a2108e-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-03-17/d57c3bec31d24720bd20ad047be14569-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-10-02/8b1a81da5a5d443fb44e07c9e9c22d0c-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-09-16/b7d033ee629a4ef2aa40f1c2b70be550-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-12-11/037cd90e226542b99dc94dfad0967412-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-07-10/71c557dea220421387b42c456a017bf9-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-07-17/5e07cd2d2ec64756a2d7117c35b120ad-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-02-20/8054848d81a646099f2f757044377a66-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-10-05/56427680a37c44c289859b2488e626a3-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-07-12/addaf4b4950e42ecaea96872da315c63-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-04-04/3d24d1e2dc914186991b4e1663c36890-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-08-31/54c773aa1d3d4aa8ad45b207ff9bed60-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-09-28/fa775408436246199e126f9934ca6f6a-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-05-17/8d28714dc4e2478db0294426a9e4580b-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-02-26/92ae0e78677740f7a13d5ff1b7eef3d0-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-03-13/1203bb972655474f8835ee91e242e409-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-11-27/0eef3bbbf1744162940c22122a083e60-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-10-27/8b1a81da5a5d443fb44e07c9e9c22d0c-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-04-21/93763a64fab54d718a62adb2ae59019a-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-08-09/3c8c8f8fbec440a98ffb82009bf7d977-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-08-08/9c536d0a889e4987bad7c0929cad5734-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-07-19/addaf4b4950e42ecaea96872da315c63-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-03-03/3b3035da6b3442afa67f0f41931bfc31-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-08-22/05df8db79d6348e18b15cea545a0737f-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-05-07/62acda0e4c0c4990bcc6db3aa5479f9e-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-11-10/db6e3be23aed4c91861c7b5997c21672-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-05-06/8d28714dc4e2478db0294426a9e4580b-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-11-01/0eef3bbbf1744162940c22122a083e60-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-01-28/5e6303bc445d47ffbbab670f071b303d-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-07-22/71c557dea220421387b42c456a017bf9-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-04-16/78b121c52618463fb4f8bef0e5a2108e-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-07-03/5e07cd2d2ec64756a2d7117c35b120ad-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-09-28/c7b584e0e3144d13a46a15a1210c72b0-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-07-01/a8805b56087a48c7a9b7d1f31888ca1e-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-07-17/d35a1f37a3db4b15920aba26b6e98c85-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-06-10/23d85a79854744fe96c8cacc5662af57-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-03-24/747a8b8ef7584adfba65805d04aecee6-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-09-08/67d5265ff6af441b91f2bed3e3bcc09c-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-11-15/db6e3be23aed4c91861c7b5997c21672-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-02-20/92ae0e78677740f7a13d5ff1b7eef3d0-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-08-20/54c773aa1d3d4aa8ad45b207ff9bed60-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-01-08/429ccdf409144a2e920d7e52442dff02-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-08-08/05df8db79d6348e18b15cea545a0737f-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-10-06/b7d8ae1e636942b8abaf72deb3f49df1-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-08-23/e131693509ea409dbccf448454b144a4-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-09-08/d4beb5727f7c4a1d8cffa731c07acb05-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-10-18/8b1a81da5a5d443fb44e07c9e9c22d0c-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-02-25/60082317d0444162b58f0ab6696875cc-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-11-22/5272b4cb6b90473d8caf862ec73d816a-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-01-04/429ccdf409144a2e920d7e52442dff02-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-05-24/678dcc5da4074d0aac053166f365a5e0-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-07-28/5e07cd2d2ec64756a2d7117c35b120ad-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-10-24/b7d8ae1e636942b8abaf72deb3f49df1-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-08-26/05df8db79d6348e18b15cea545a0737f-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-10-29/56427680a37c44c289859b2488e626a3-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-06-15/e970ad8c85a845f1ba2ac187411817a0-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-11-27/87f5ac967e474052b6c9779f804ee860-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-09-29/d4beb5727f7c4a1d8cffa731c07acb05-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-03-09/cb5dea63b8f74a1e8e828ee3b137e2fc-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-09-17/61b05420237f45e6b382db523812deea-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-05-17/678dcc5da4074d0aac053166f365a5e0-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-04-22/57d1a2ed2feb40ffbfdc1cb7bcfe707f-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-01-07/da95c6f5e9184a22806b9370501695c9-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-01-27/da95c6f5e9184a22806b9370501695c9-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-03-20/1203bb972655474f8835ee91e242e409-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-10-22/f68ef0781ee14733b255a56c02979e24-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-02-04/92ae0e78677740f7a13d5ff1b7eef3d0-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-07-23/a8805b56087a48c7a9b7d1f31888ca1e-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-04-23/8162144895c44ff1a8ade25633efe296-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-01-09/37c1ddf4963f4e30acd4b8429a5e6fe3-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2021-07-22/addaf4b4950e42ecaea96872da315c63-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-01-10/37c1ddf4963f4e30acd4b8429a5e6fe3-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-07-21/cb51cdcfb88f456bb3c0109d09643ba2-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2025-02-18/92ae0e78677740f7a13d5ff1b7eef3d0-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2020-02-06/8054848d81a646099f2f757044377a66-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2024-07-11/d35a1f37a3db4b15920aba26b6e98c85-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2022-07-18/cb51cdcfb88f456bb3c0109d09643ba2-0.parquet',
#  '../data/raw/adrs/bbo-1m/by_exchange/exchange=XNAS.ITCH/ticker=SAP/date=2023-07-31/5e07cd2d2ec64756a2d7117c35b120ad-0.parquet',
#  ...]

# %%
dataset_path='../data/raw/adrs/bbo-1m/none/'
dataset = ds.dataset(dataset_path, format="parquet", partitioning="hive")

# %%
combos, combo_dates = discover_partition_combos_from_paths(
    dataset_path='../data/raw/adrs/bbo-1m/by_exchange/',date_column='date',combo_cols=['exchange','ticker']
)

# %%
import os

def discover_partition_combos_from_paths(
    dataset_path: str,
    combo_cols: List[str],
    date_column: str,
) -> Tuple[List[Tuple[Any, ...]], Dict[Tuple[Any, ...], List[pd.Timestamp]]]:
    """
    FAST VERSION:

    Walk the *directory tree* (not individual Parquet files) to discover:

    - All unique combinations of values for `combo_cols` (non-date partition columns).
    - For each combination, the list of dates if `date_column` is a partition key
      in the directory structure.

    Assumes Hive-style partitioning: e.g.
        root/exchange=ARCX.PILLAR/ticker=AEG/date=2020-01-02/part-0.parquet

    Returns:
        combos: list of tuple(combo_values) in the order of combo_cols.
        combo_dates: mapping combo_key -> list of pd.Timestamp (only those combos
                     where `date_column` appears as a partition key).
    """
    dataset_path = os.path.abspath(dataset_path)

    combo_set = set()
    # store date *strings* during walk, convert to Timestamp once at the end
    combo_date_strings: Dict[Tuple[Any, ...], set] = defaultdict(set)

    for dirpath, dirnames, filenames in os.walk(dataset_path):
        rel = os.path.relpath(dirpath, dataset_path)
        if rel == ".":
            # root itself; no partition components here
            continue

        parts = rel.split(os.sep)
        part_dict = parse_partition_components(parts)

        # Build combo key from combo_cols (may be empty tuple if no non-date partition cols)
        combo_key = tuple(part_dict.get(col) for col in combo_cols)
        
        # We only care about directories that actually correspond to some partition level
        if all(val is not None for val in combo_key) or (date_column in part_dict):
            combo_set.add(combo_key)

        # Capture date if it is present as a partition component
        if date_column in part_dict:
            combo_date_strings[combo_key].add(part_dict[date_column])

    combos = sorted(combo_set)
   
    # Convert date strings to normalized Timestamp lists in one shot
    combo_dates: Dict[Tuple[Any, ...], List[pd.Timestamp]] = {}
    for key, date_strs in combo_date_strings.items():
        # sort lexicographically first (cheap), then convert
        sorted_strs = sorted(date_strs)
        ts = pd.to_datetime(sorted_strs).normalize()
        combo_dates[key] = list(ts)

    return combos, combo_dates

# %%
import sys
sys.path.append('../src')
import utils

# %%
cbday = utils.get_market_business_days('XNYS')
present_days = pd.date_range('2020-01-02','2025-11-07',freq=cbday)
expected_days = trading_days

# %%
ranges
# Out:
# [(Timestamp('2019-12-16 00:00:00'), Timestamp('2019-12-31 00:00:00')),
#  (Timestamp('2025-11-10 00:00:00'), Timestamp('2025-12-02 00:00:00'))]
